# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /home/nik/anaconda3/envs/deepl/lib/python3.6/site-packages (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in /home/nik/anaconda3/envs/deepl/lib/python3.6/site-packages (from beautifulsoup4) (2.3.2.post1)

# %%
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in /home/nik/anaconda3/envs/deepl/lib/python3.6/site-packages (4.8.0)

# %%
import bs4 as bs
import urllib.request

# %%
source = urllib.request.urlopen('https://simple.wikipedia.org/wiki/Global_warming').read()

# %%
source
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Global warming - Simple English Wikipedia, the free encyclopedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"a3f012e7-a0b9-4cac-9f24-81d295760576","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Global_warming","wgTitle":"Global warming","wgCurRevisionId":8285778,"wgRevisionId":8285778,"wgArticleId":7368,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 maint: url-status","Webarchive template wayback links","Energy","Climate change","Air pollution"],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Global_warming","wgRelevantArticleId":7368,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,\n"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":20000,"wgNoticeProject":"wikipedia","wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":10,"wgULSCurrentAutonym":"English","wgEditSubmitButtonLabelPublish":true,"wgCentralAuthMobileDomain":false,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":true,"wgWikibaseItemId":"Q7942","GEHomepageSuggestedEditsEnableTopics":true,"wgGETopicsMatchModeEnabled":false};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","skins.vector.styles.legacy":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.wikimediaBadges"\n:"ready","ext.uls.interlanguage":"ready","wikibase.client.init":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.ready","mediawiki.toc","skins.vector.legacy.js","mmv.head","mmv.bootstrap.autostart","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.cx.eventlogging.campaigns","ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.gadget.ReferenceTooltips","ext.gadget.refToolbar","ext.gadget.switcher","ext.centralauth.centralautologin","ext.popups","ext.uls.compactlinks","ext.uls.interface","ext.growthExperiments.SuggestedEditSession"];</script>\n<script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@12s5i",function($,jQuery,require,module){mw.user.tokens.set({"patrolToken":"+\\\\","watchToken":"+\\\\","csrfToken":"+\\\\"});});});</script>\n<link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cskins.vector.styles.legacy%7Cwikibase.client.init&amp;only=styles&amp;skin=vector"/>\n<script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector"></script>\n<meta name="ResourceLoaderDynamicStyles" content=""/>\n<link rel="stylesheet" href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector"/>\n<meta name="generator" content="MediaWiki 1.39.0-wmf.16"/>\n<meta name="referrer" content="origin"/>\n<meta name="referrer" content="origin-when-crossorigin"/>\n<meta name="referrer" content="origin-when-cross-origin"/>\n<meta name="format-detection" content="telephone=no"/>\n<meta property="og:image" content="https://upload.wikimedia.org/wikipedia/commons/thumb/a/a0/202003 ...

# %%
soup = bs.BeautifulSoup(source,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Global warming - Simple English Wikipedia, the free encyclopedia</title>
# <script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"a3f012e7-a0b9-4cac-9f24-81d295760576","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Global_warming","wgTitle":"Global warming","wgCurRevisionId":8285778,"wgRevisionId":8285778,"wgArticleId":7368,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 maint: url-status","Webarchive template wayback links","Energy","Climate change","Air pollution"],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Global_warming","wgRelevantArticleId":7368,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,
# "wgRestrictionEdit":[],"wgRestrictionMove":[],"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":true},"wgWMESchemaEditAttemptStepOversample":false,"wgWMEPageLength":20000,"wgNoticeProject":"wikipedia","wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsFlags":10,"wgULSCurrentAutonym":"English","wgEditSubmitButtonLabelPublish":true,"wgCentralAuthMobileDomain":false,"wgULSPosition":"interlanguage","wgULSisCompactLinksEnabled":true,"wgWikibaseItemId":"Q7942","GEHomepageSuggestedEditsEnableTopics":true,"wgGETopicsMatchModeEnabled":false};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","skins.vector.styles.legacy":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.wikimediaBadges"
# :"ready","ext.uls.interlanguage":"ready","wikibase.client.init":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.ready","mediawiki.toc","skins.vector.legacy.js","mmv.head","mmv.bootstrap.autostart","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.cx.eventlogging.campaigns","ext.centralNotice.geoIP","ext.centralNotice.startUp","ext.gadget.ReferenceTooltips","ext.gadget.refToolbar","ext.gadget.switcher","ext.centralauth.centralautologin","ext.popups","ext.uls.compactlinks","ext.uls.interface","ext.growthExperiments.SuggestedEditSession"];</script>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@12s5i",function($,jQuery,require,module){mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});});});</script>
# <link href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cskins.vector.styles.legacy%7Cwikibase.client.init&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
# <script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector"></script>
# <meta content="" name="ResourceLoaderDynamicStyles"/>
# <link href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
# <meta content="MediaWiki 1.39.0-wmf.16" name="generator"/>
# <meta content="origin" name="referrer"/>
# <meta content="origin-when-crossorigin" name="referrer"/>
# <meta content="origin-when-cross-origin" name="referrer"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="https://upload.wikimedia.org/wikipedia/commons/thumb/a/a0/20200324_Global_average_temperature_-_NASA-GISS_HadCrut_NOAA_Japan_BerkeleyE.svg/1200px-20200324_Global_average_temperature_-_NASA-GISS_HadCrut_NOAA_Japan_BerkeleyE.svg.png" property="og:image"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="900" property="og:image:height"/>
# <meta content="https://upload.wikimedia.org/wikipedia/commons/thumb/a/a0/20200324_Global_average_temperature_-_NASA-GISS_HadCrut_NOAA_Japan_BerkeleyE.svg/800px-20200324_Global_average_temperature_-_NASA-GISS_HadCrut_NOAA_Japan_BerkeleyE.svg.png" property="og:image"/>
# <meta content="800" property="og:image:width"/>
# <meta content="600" property="og:image:height"/>
# <meta content="https://upload.wikimedia.org/wikipedia/commons/thumb/a/a0/20200324_Global_average_temperature_-_NASA-GISS_HadCrut_NOAA_Japan_BerkeleyE.svg/640px-20200324_Global_average_temperature_-_NASA-GISS_HadCrut_NOAA_Japan_BerkeleyE.svg.png" property="og:image"/>
# <meta content="640" property="og:image:width"/>
# <meta content="480" property="og:image:height"/>
# <meta content="Global warming - Simple English Wikipedia, the free encyclopedia" property="og:title"/>
# <meta content="website" property="og:type"/>
# <link href="//upload.wikimedia.org" rel="preconnect"/>
# <link href="//simple.m.wikipedia.org/wiki/Global_warming" media="only screen and (max-width: 720px)" rel="alternate"/>
# <link href="/w/index.php?title=Global_warming&amp;action=edit" rel="alternate" title="change this page" type="application/x-wiki"/>
# <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
# <link href="/static/favicon/wikipedia.ico" rel="shortcut icon"/>
# <link href="/w/opensearch_desc.php" rel="search" title="Wikipedia (en)" type="application/opensearchdescription+xml"/>
# <link href="//simple.wikipedia.org/w/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>
# <link href="https://creativecommons.org/licenses/by-sa/3.0/" rel="license"/>
# <link href="https://simple.wikipedia.org/wiki/Global_warming" rel="canonical"/>
# <link href="//meta.wikimedia.org" rel="dns-prefetch"/>
# <link href="//login.wikimedia.org" rel="dns-prefetch"/>
# </head>
# <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject mw-editable page-Global_warming rootpage-Global_warming skin-vector action-view skin-vector-legacy"><div class="noprint" id="mw-page-base"></div>
# <div class="noprint" id="mw-head-base"></div>
# <div class="mw-body" id="content" role="main">
# <a id="top"></a>
# <div id="siteNotice"><!-- CentralNotice --></div>
# <div class="mw-indicators">
# </div>
# <h1 class="firstHeading mw-first-heading" id="firstHeading">Global warming</h1>
# <div class="vector-body" id="bodyContent">
# <div class="noprint" id="siteSub">From Simple English Wikipedia, the free encyclopedia</div>
# <div id="contentSub"></div>
# <div id="contentSub2"></div>
# <div id="jump-to-nav"></div>
# <a class="mw-jump-link" href="#mw-head">Jump to navigation</a>
# <a class="mw-jump-link" href="#searchInput">Jump to search</a>
# <div class="mw-body-content mw-content-ltr" dir="ltr" id="mw-content-text" lang="en"><div class="mw-parser-output"><style data-mw-deduplicate="TemplateStyles:r7707418">.mw-parser-output .hatnote{font-style:italic}.mw-parser-output div.hatnote{padding-left:1.6em;margin-bottom:0.5em}.mw-parser-output .hatnote i{font-style:normal}.mw-parser-output .hatnote+link+.hatnote{margin-top:-0.5em}</style><div class="hatnote navigation-not-searchable" role="note">This article is about climate change happening on Earth now. For climate change a long time ago, see <a class="mw-redirect" href="/wiki/Climate_variability_and_change" title="Climate variability and change">Climate variability and change</a>.</div>
# <div class="thumb tright"><div class="thumbinner" style="width:292px;"><a class="image" href="/wiki/File:20200324_Global_average_temperature_-_NASA-GISS_HadCrut_NOAA_Japan_BerkeleyE.svg"><img alt="" class="thumbimage" data-file-height="750" data-file-width="1000" decoding="async" height="218" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/a0/20200324_Global_average_temperature_-_NASA-GISS_HadCrut_NOAA_Japan_BerkeleyE.svg/290px-20200324_Global_average_temperature_-_NASA-GISS_HadCrut_NOAA_Japan_BerkeleyE.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/a0/20200324_Global_average_temperature_-_NASA-GISS_HadCrut_NOAA_Japan_BerkeleyE.svg/435px-20200324_Global_average_temperature_-_NASA-GISS_HadCrut_NOAA_Japan_BerkeleyE.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/a0/20200324_Global_average_temperature_-_NASA-GISS_HadCrut_NOAA_Japan_BerkeleyE.svg/580px-20200324_Global_average_temperature_-_NASA-GISS_HadCrut_NOAA_Japan_BerkeleyE.svg.png 2x" width="290"/></a> <div class="thumbcaption"><div class="magnify"><a class="internal" href="/wiki/File:20200324_Global_average_temperature_-_NASA-GISS_HadCrut_NOAA_Japan_BerkeleyE.svg" title="Enlarge"></a></div>Global average temperature, shown by measurements from various sources, has increased since the <a href="/wiki/Industrial_Revolution" title="Industrial Revolution">Industrial Revolution</a>.</div></div></div>
# <div class="thumb tright"><div class="thumbinner" style="width:292px;"><a class="image" href="/wiki/File:Change_in_Average_Temperature.svg"><img alt="" class="thumbimage" data-file-height="816" data-file-width="960" decoding="async" height="247" src="//upload.wikimedia.org/wikipedia/commons/thumb/8/88/Change_in_Average_Temperature.svg/290px-Change_in_Average_Temperature.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/8/88/Change_in_Average_Temperature.svg/435px-Change_in_Average_Temperature.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/8/88/Change_in_Average_Temperature.svg/580px-Change_in_Average_Temperature.svg.png 2x" width="290"/></a> <div class="thumbcaption"><div class="magnify"><a class="internal" href="/wiki/File:Change_in_Average_Temperature.svg" title="Enlarge"></a></div>Places that got warmer (red) and cooler (blue) over the past 50 years</div></div></div><p><b>Global warming</b> is the current rise in <a href="/wiki/Temperature" title="Temperature">temperature</a> of the air and oceans. It happens because humans burn <a href="/wiki/Coal" title="Coal">coal</a>, <a href="/wiki/Oil" title="Oil">oil</a> and <a href="/wiki/Natural_gas" title="Natural gas">natural gas</a>, and cut down forests.<sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup> Average temperatures today are about 1 °C (1.8 °F) higher than before <a href="/wiki/Industrial_Revolution" title="Industrial Revolution">people started burning a lot of coal</a> around 1750.<sup class="reference" id="cite_ref-:0_2-0"><a href="#cite_note-:0-2">[2]</a></sup> In some parts of the world it is less and some more. Most climate <a href="/wiki/Scientist" title="Scientist">scientists</a> say that by the year 2100 temperatures will be 2 °C (3.6 °F) to  4 °C (7.2 °F) higher than they were before 1750.<sup class="reference" id="cite_ref-3"><a href="#cite_note-3">[3]</a></sup> The extra warmth melts ice caps around the world. Sea level is rising for two reasons: ice on the land, like <a href="/wiki/Greenland" title="Greenland">Greenland</a>, melts into the sea. Water also gets larger when it warms. Many cities will be partly flooded by the ocean in the 21st century.
# </p><p>Global warming is mostly because of people burning things, like <a href="/wiki/Gasoline" title="Gasoline">gasoline</a> for cars and <a href="/wiki/Natural_gas" title="Natural gas">natural gas</a> to keep houses warm. But the heat from the burning itself only makes the world a tiny bit warmer: it is the <a href="/wiki/Carbon_dioxide" title="Carbon dioxide">carbon dioxide</a> from the burning which is the biggest part of the problem. Among the <a href="/wiki/Greenhouse_gas" title="Greenhouse gas">greenhouse gases</a>, the increase of carbon dioxide in the <a class="mw-redirect" href="/wiki/Atmosphere" title="Atmosphere">atmosphere</a> is the main cause of global warming, as predicted by <a href="/wiki/Svante_Arrhenius" title="Svante Arrhenius">Svante Arrhenius</a> a hundred years ago, confirming the work of <a href="/wiki/Joseph_Fourier" title="Joseph Fourier">Joseph Fourier</a> more than 200 years ago. When people <a href="/wiki/Combustion" title="Combustion">burn</a> <a class="mw-redirect" href="/wiki/Fossil_fuels" title="Fossil fuels">fossil fuels</a> like <a href="/wiki/Coal" title="Coal">coal</a>, <a href="/wiki/Oil" title="Oil">oil</a> and <a href="/wiki/Natural_gas" title="Natural gas">natural gas</a> this adds <a href="/wiki/Carbon_dioxide" title="Carbon dioxide">carbon dioxide</a> into the air.<sup class="reference" id="cite_ref-4"><a href="#cite_note-4">[4]</a></sup> This is because fossil fuels contain lots of <a href="/wiki/Carbon" title="Carbon">carbon</a> and burning means joining most of the <a href="/wiki/Atom" title="Atom">atoms</a> in the fuel with <a href="/wiki/Oxygen" title="Oxygen">oxygen</a>. When people cut down many trees (<a href="/wiki/Deforestation" title="Deforestation">deforestation</a>), this means less carbon dioxide is taken out of the atmosphere by those <a class="mw-redirect" href="/wiki/Plants" title="Plants">plants</a>. The gas produced by cows digestion also causes global warming, because it contains a greenhouse gas called <a href="/wiki/Methane" title="Methane">methane</a>.<sup class="reference" id="cite_ref-5"><a href="#cite_note-5">[5]</a></sup>
# </p><p>As the Earth's surface temperature becomes hotter the <a href="/wiki/Sea_level" title="Sea level">sea level</a> rises. This is partly because water over 4 °C (39 °F) <a href="/wiki/Thermal_expansion" title="Thermal expansion">expands when it gets warmer</a>.<sup class="reference" id="cite_ref-Mosher_6-0"><a href="#cite_note-Mosher-6">[6]</a></sup> It is also partly because warm temperatures make <a href="/wiki/Glacier" title="Glacier">glaciers</a> and <a href="/wiki/Ice_cap" title="Ice cap">ice caps</a> melt. The sea level rise causes <a href="/wiki/Coast" title="Coast">coastal</a> areas to <a href="/wiki/Flood" title="Flood">flood</a>.<sup class="reference" id="cite_ref-7"><a href="#cite_note-7">[7]</a></sup> Weather patterns, including where and how much <a href="/wiki/Precipitation" title="Precipitation">rain or snow</a> there is, are changing. <a href="/wiki/Desert" title="Desert">Deserts</a> will probably increase in size. Colder areas will warm up faster than warm areas. Strong <a href="/wiki/Storm" title="Storm">storms</a> may become more likely and <a href="/wiki/Farming" title="Farming">farming</a> may not make as much <a href="/wiki/Food" title="Food">food</a>. These effects will not be the same everywhere. The changes from one area to another are not well known.
# </p><p>Governments have agreed to keep temperature rise below 2 °C (3.6 °F), but current plans by governments are not enough to limit global warming that much.<sup class="reference" id="cite_ref-8"><a href="#cite_note-8">[8]</a></sup>
# </p><p>People in <a href="/wiki/Government" title="Government">government</a> and the <a href="/wiki/Intergovernmental_Panel_on_Climate_Change" title="Intergovernmental Panel on Climate Change">Intergovernmental Panel on Climate Change</a> (IPCC) are talking about global warming. But governments, <a href="/wiki/Company" title="Company">companies,</a> and other people do not agree on what to do about it. Some things that could reduce warming are to burn less fossil fuels, grow more trees, eat less meat, and put some carbon dioxide back in the ground. People could adapt to some temperature change. The <a href="/wiki/Kyoto_Protocol" title="Kyoto Protocol">Kyoto Protocol</a> and <a href="/wiki/Paris_Agreement" title="Paris Agreement">Paris Agreement</a> try to reduce <a href="/wiki/Pollution" title="Pollution">pollution</a> from the burning of fossil fuels. Most <a href="/wiki/Government" title="Government">governments</a> have agreed to them but some people in government think nothing should change.
# </p>
# <div aria-labelledby="mw-toc-heading" class="toc" id="toc" role="navigation"><input class="toctogglecheckbox" id="toctogglecheckbox" role="button" style="display:none" type="checkbox"/><div class="toctitle" dir="ltr" lang="en"><h2 id="mw-toc-heading">Contents</h2><span class="toctogglespan"><label class="toctogglelabel" for="toctogglecheckbox"></label></span></div>
# <ul>
# <li class="toclevel-1 tocsection-1"><a href="#Temperature_changes"><span class="tocnumber">1</span> <span class="toctext">Temperature changes</span></a>
# <ul>
# <li class="toclevel-2 tocsection-2"><a href="#Greenhouse_gases"><span class="tocnumber">1.1</span> <span class="toctext">Greenhouse gases</span></a></li>
# <li class="toclevel-2 tocsection-3"><a href="#Dust_and_dirt"><span class="tocnumber">1.2</span> <span class="toctext">Dust and dirt</span></a></li>
# </ul>
# </li>
# <li class="toclevel-1 tocsection-4"><a href="#Slowing_climate_change"><span class="tocnumber">2</span> <span class="toctext">Slowing climate change</span></a></li>
# <li class="toclevel-1 tocsection-5"><a href="#Dealing_with_impacts_of_climate_change"><span class="tocnumber">3</span> <span class="toctext">Dealing with impacts of climate change</span></a></li>
# <li class="toclevel-1 tocsection-6"><a href="#History_of_climate_change_science"><span class="tocnumber">4</span> <span class="toctext">History of climate change science</span></a></li>
# <li class="toclevel-1 tocsection-7"><a href="#Effects_of_global_warming_on_sea_levels"><span class="tocnumber">5</span> <span class="toctext">Effects of global warming on sea levels</span></a>
# <ul>
# <li class="toclevel-2 tocsection-8"><a href="#Cities_affected_by_current_sea_level_rise"><span class="tocnumber">5.1</span> <span class="toctext">Cities affected by current sea level rise</span></a></li>
# </ul>
# </li>
# <li class="toclevel-1 tocsection-9"><a href="#Further_reading"><span class="tocnumber">6</span> <span class="toctext">Further reading</span></a></li>
# <li class="toclevel-1 tocsection-10"><a href="#Related_pages"><span class="tocnumber">7</span> <span class="toctext">Related pages</span></a></li>
# <li class="toclevel-1 tocsection-11"><a href="#References"><span class="tocnumber">8</span> <span class="toctext">References</span></a></li>
# <li class="toclevel-1 tocsection-12"><a href="#Other_websites"><span class="tocnumber">9</span> <span class="toctext">Other websites</span></a></li>
# </ul>
# </div>
# <h2><span class="mw-headline" id="Temperature_changes">Temperature changes</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a class="mw-editsection-visualeditor" href="/w/index.php?title=Global_warming&amp;veaction=edit&amp;section=1" title="Change section: Temperature changes">change</a><span class="mw-editsection-divider"> | </span><a href="/w/index.php?title=Global_warming&amp;action=edit&amp;section=1" title="Change section: Temperature changes">change source</a><span class="mw-editsection-bracket">]</span></span></h2>
# <link href="mw-data:TemplateStyles:r7707418" rel="mw-deduplicated-inline-style"/><div class="hatnote navigation-not-searchable" role="note">See also: <a href="/wiki/Temperature_record_of_the_past_1000_years" title="Temperature record of the past 1000 years">Temperature record of the past 1000 years</a></div>
# <div class="center"><div class="thumb tnone"><div class="thumbinner" style="width:452px;"><a class="image" href="/wiki/File:2000%2B_year_global_temperature_including_Medieval_Warm_Period_and_Little_Ice_Age_-_Ed_Hawkins.svg"><img alt="" class="thumbimage" data-file-height="1080" data-file-width="1920" decoding="async" height="253" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/f8/2000%2B_year_global_temperature_including_Medieval_Warm_Period_and_Little_Ice_Age_-_Ed_Hawkins.svg/450px-2000%2B_year_global_temperature_including_Medieval_Warm_Period_and_Little_Ice_Age_-_Ed_Hawkins.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/f8/2000%2B_year_global_temperature_including_Medieval_Warm_Period_and_Little_Ice_Age_-_Ed_Hawkins.svg/675px-2000%2B_year_global_temperature_including_Medieval_Warm_Period_and_Little_Ice_Age_-_Ed_Hawkins.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/f8/2000%2B_year_global_temperature_including_Medieval_Warm_Period_and_Little_Ice_Age_-_Ed_Hawkins.svg/900px-2000%2B_year_global_temperature_including_Medieval_Warm_Period_and_Little_Ice_Age_-_Ed_Hawkins.svg.png 2x" width="450"/></a> <div class="thumbcaption"><div class="magnify"><a class="internal" href="/wiki/File:2000%2B_year_global_temperature_including_Medieval_Warm_Period_and_Little_Ice_Age_-_Ed_Hawkins.svg" title="Enlarge"></a></div>A graph of temperatures over the past two thousand years. The so-called <a href="/wiki/Medieval_Warm_Period" title="Medieval Warm Period">Medieval Warm Period</a> and <a href="/wiki/Little_Ice_Age" title="Little Ice Age">Little Ice Age</a> were regional phenomena, and were not experienced worldwide.</div></div></div></div>
# <p><a href="/wiki/Climate_change" title="Climate change">Climate change</a> has happened constantly over the <a href="/wiki/History_of_the_Earth" title="History of the Earth">history of the Earth</a>, including the coming and going of <a href="/wiki/Ice_age" title="Ice age">ice ages</a>. But modern climate change is different because people are putting carbon dioxide into the atmosphere very quickly.<sup class="reference" id="cite_ref-9"><a href="#cite_note-9">[9]</a></sup>
# </p><p>Since the 1800s, people have recorded the daily temperature. By about 1850, there were enough places measuring temperature so that scientists could know the global <a href="/wiki/Average" title="Average">average</a> temperature. Compared with before people started burning a lot of <a href="/wiki/Coal" title="Coal">coal</a> for <a href="/wiki/Industry" title="Industry">industry</a>, the temperature has risen by about 1 °C (1.8 °F).<sup class="reference" id="cite_ref-:0_2-1"><a href="#cite_note-:0-2">[2]</a></sup> In 1979, <a href="/wiki/Satellite_(artificial)" title="Satellite (artificial)">satellites</a> started measuring the temperature of the Earth.<sup class="reference" id="cite_ref-10"><a href="#cite_note-10">[10]</a></sup>
# </p><p>Before 1850, there were not enough temperature measurements for us to know how warm or cold it was. <a href="/wiki/Climatology" title="Climatology">Climatologists</a> use <a class="mw-disambig" href="/wiki/Proxy" title="Proxy">proxy</a> measurements to try to figure out past temperatures before there were <a href="/wiki/Thermometer" title="Thermometer">thermometers</a>. This means measuring things that change when it gets colder or warmer. One way is to cut into a tree and measure how far apart the <a href="/wiki/Growth_ring" title="Growth ring">growth rings</a> are. Trees that live a long time can give us an idea of how <a href="/wiki/Temperature" title="Temperature">temperature</a> and <a href="/wiki/Rain" title="Rain">rain</a> changed while they were alive.
# </p><p>For most of the past 2000 years the average temperature of the world didn't change much. There were some times where the temperatures were a little warmer or cooler in some places. One of the most famous warm times was the <a href="/wiki/Medieval_Warm_Period" title="Medieval Warm Period">Medieval Warm Period</a> and one of the most famous cool times was the <a href="/wiki/Little_Ice_Age" title="Little Ice Age">Little Ice Age</a> (not really an <a href="/wiki/Ice_age" title="Ice age">ice age</a>). Other proxy measurements like the temperature measured in deep holes mostly agree with the tree rings. Tree rings and bore holes can only help scientists work out the temperature back to about 2000 years ago. <a href="/wiki/Ice_core" title="Ice core">Ice cores</a> are also used to find out the temperature back to about half a million years ago.
# </p>
# <h3><span class="mw-headline" id="Greenhouse_gases">Greenhouse gases</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a class="mw-editsection-visualeditor" href="/w/index.php?title=Global_warming&amp;veaction=edit&amp;section=2" title="Change section: Greenhouse gases">change</a><span class="mw-editsection-divider"> | </span><a href="/w/index.php?title=Global_warming&amp;action=edit&amp;section=2" title="Change section: Greenhouse gases">change source</a><span class="mw-editsection-bracket">]</span></span></h3>
# <link href="mw-data:TemplateStyles:r7707418" rel="mw-deduplicated-inline-style"/><div class="hatnote navigation-not-searchable" role="note">Main article: <a href="/wiki/Greenhouse_effect" title="Greenhouse effect">Greenhouse effect</a></div>
# <div class="thumb tright"><div class="thumbinner" style="width:222px;"><a class="image" href="/wiki/File:Global_Warming_Observed_CO2_Emissions_from_fossil_fuel_burning_vs_IPCC_scenarios.svg"><img alt="" class="thumbimage" data-file-height="470" data-file-width="660" decoding="async" height="157" src="//upload.wikimedia.org/wikipedia/commons/thumb/2/2d/Global_Warming_Observed_CO2_Emissions_from_fossil_fuel_burning_vs_IPCC_scenarios.svg/220px-Global_Warming_Observed_CO2_Emissions_from_fossil_fuel_burning_vs_IPCC_scenarios.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/2/2d/Global_Warming_Observed_CO2_Emissions_from_fossil_fuel_burning_vs_IPCC_scenarios.svg/330px-Global_Warming_Observed_CO2_Emissions_from_fossil_fuel_burning_vs_IPCC_scenarios.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/2/2d/Global_Warming_Observed_CO2_Emissions_from_fossil_fuel_burning_vs_IPCC_scenarios.svg/440px-Global_Warming_Observed_CO2_Emissions_from_fossil_fuel_burning_vs_IPCC_scenarios.svg.png 2x" width="220"/></a> <div class="thumbcaption"><div class="magnify"><a class="internal" href="/wiki/File:Global_Warming_Observed_CO2_Emissions_from_fossil_fuel_burning_vs_IPCC_scenarios.svg" title="Enlarge"></a></div>Fossil fuel related CO<sub>2</sub> emissions compared to five IPCC scenarios. The dips are related to global recessions.</div></div></div>
# <p>There a many <a href="/wiki/Greenhouse_gas" title="Greenhouse gas">greenhouse gases</a> that cause the Earth to warm. The most important one is carbon dioxide (CO<sub>2</sub>). CO<sub>2</sub> comes from <a href="/wiki/Power_station" title="Power station">power plants</a>, where coal and natural gas are burnt. Cars also emit CO<sub>2</sub> when they burn petrol. About 23 billion tons of carbon dioxide and other <a href="/wiki/Greenhouse_gas" title="Greenhouse gas">greenhouse gases</a> are released into the Earth's atmosphere each year. The amount of CO<sub>2</sub> in the air is about 48% more than it was around 1750.<sup class="reference" id="cite_ref-11"><a href="#cite_note-11">[11]</a></sup> About three-quarters of the CO<sub>2</sub> that people have put in the air during the past 20 years are due to burning <a href="/wiki/Fossil_fuel" title="Fossil fuel">fossil fuel</a> like coal or oil. The rest mostly comes from changes in how land is used, like <a href="/wiki/Deforestation" title="Deforestation">cutting down trees</a>.<sup class="reference" id="cite_ref-12"><a href="#cite_note-12">[12]</a></sup>
# </p><p>The second most important greenhouse gas is methane. This comes mostly from food production. Some methane also leaks when oil and gas are produced.<sup class="reference" id="cite_ref-13"><a href="#cite_note-13">[13]</a></sup>
# </p>
# <h3><span class="mw-headline" id="Dust_and_dirt">Dust and dirt</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a class="mw-editsection-visualeditor" href="/w/index.php?title=Global_warming&amp;veaction=edit&amp;section=3" title="Change section: Dust and dirt">change</a><span class="mw-editsection-divider"> | </span><a href="/w/index.php?title=Global_warming&amp;action=edit&amp;section=3" title="Change section: Dust and dirt">change source</a><span class="mw-editsection-bracket">]</span></span></h3>
# <p><a href="/wiki/Dust" title="Dust">Dust</a> and <a class="mw-disambig" href="/wiki/Dirt" title="Dirt">dirt</a> in the air may come from natural sources such as <a href="/wiki/Volcano" title="Volcano">volcanos</a>,<sup class="reference" id="cite_ref-14"><a href="#cite_note-14">[14]</a></sup><sup class="reference" id="cite_ref-15"><a href="#cite_note-15">[15]</a></sup> <a href="/wiki/Erosion" title="Erosion">erosion</a> and <a href="/wiki/Meteor" title="Meteor">meteoric</a> dust. Some of this dirt falls out within a few hours. Some is <a href="/wiki/Aerosol" title="Aerosol">aerosol</a>, so small that it could stay in the air for years. The aerosol particles in the atmosphere make the earth colder. The effect of dust therefore cancels out some of the effects of greenhouse gases.<sup class="reference" id="cite_ref-16"><a href="#cite_note-16">[16]</a></sup> Even though humans also put aerosols in the air when they burn coal or oil this only cancels out the greenhouse effect of the fuel burning for less than 20 years: however the carbon dioxide stays in the atmosphere much longer and keeps on warming the earth.<sup class="reference" id="cite_ref-17"><a href="#cite_note-17">[17]</a></sup>
# </p>
# <h2><span class="mw-headline" id="Slowing_climate_change">Slowing climate change</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a class="mw-editsection-visualeditor" href="/w/index.php?title=Global_warming&amp;veaction=edit&amp;section=4" title="Change section: Slowing climate change">change</a><span class="mw-editsection-divider"> | </span><a href="/w/index.php?title=Global_warming&amp;action=edit&amp;section=4" title="Change section: Slowing climate change">change source</a><span class="mw-editsection-bracket">]</span></span></h2>
# <p>Some people burn less fossil fuel. Countries try to emit less greenhouse gases. The <a href="/wiki/Kyoto_Protocol" title="Kyoto Protocol">Kyoto Protocol</a> was signed in 1997. It was meant to reduce the amount of greenhouse gases in the atmosphere to below their levels in 1990. However, carbon dioxide levels have continued to rise.
# </p><p><a href="/wiki/Energy_conservation" title="Energy conservation">Energy conservation</a> is used to burn less fossil fuel. People can also use energy sources that don't burn fossil fuel, like <a href="/wiki/Solar_panel" title="Solar panel">solar panels</a> or electricity from <a href="/wiki/Nuclear_power" title="Nuclear power">nuclear power</a> or <a href="/wiki/Wind_power" title="Wind power">wind power</a>. Or they can prevent the carbon dioxide from getting out into the atmosphere, which is called carbon capture and storage (CCS).
# </p>
# <h2><span class="mw-headline" id="Dealing_with_impacts_of_climate_change">Dealing with impacts of climate change</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a class="mw-editsection-visualeditor" href="/w/index.php?title=Global_warming&amp;veaction=edit&amp;section=5" title="Change section: Dealing with impacts of climate change">change</a><span class="mw-editsection-divider"> | </span><a href="/w/index.php?title=Global_warming&amp;action=edit&amp;section=5" title="Change section: Dealing with impacts of climate change">change source</a><span class="mw-editsection-bracket">]</span></span></h2>
# <p>People can change how they live because of the effect of climate change. For example, they can go to places where the weather is better, or build walls around cities to keep flood water out. This cost money, and rich people and rich countries will be able to change more easily than the poor.
# </p>
# <h2><span class="mw-headline" id="History_of_climate_change_science">History of climate change science</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a class="mw-editsection-visualeditor" href="/w/index.php?title=Global_warming&amp;veaction=edit&amp;section=6" title="Change section: History of climate change science">change</a><span class="mw-editsection-divider"> | </span><a href="/w/index.php?title=Global_warming&amp;action=edit&amp;section=6" title="Change section: History of climate change science">change source</a><span class="mw-editsection-bracket">]</span></span></h2>
# <div class="thumb tright"><div class="thumbinner" style="width:130px;"><a class="image" href="/wiki/File:Joseph_Fourier.jpg"><img alt="" class="thumbimage" data-file-height="984" data-file-width="805" decoding="async" height="156" src="//upload.wikimedia.org/wikipedia/commons/thumb/a/aa/Joseph_Fourier.jpg/128px-Joseph_Fourier.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/a/aa/Joseph_Fourier.jpg/191px-Joseph_Fourier.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/a/aa/Joseph_Fourier.jpg/255px-Joseph_Fourier.jpg 2x" width="128"/></a> <div class="thumbcaption"><div class="magnify"><a class="internal" href="/wiki/File:Joseph_Fourier.jpg" title="Enlarge"></a></div>Joseph Fourier; first to explain climate change</div></div></div>
# <div class="thumb tright"><div class="thumbinner" style="width:128px;"><a class="image" href="/wiki/File:Arrhenius2.jpg"><img alt="" class="thumbimage" data-file-height="600" data-file-width="479" decoding="async" height="158" src="//upload.wikimedia.org/wikipedia/commons/thumb/6/6c/Arrhenius2.jpg/126px-Arrhenius2.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/6/6c/Arrhenius2.jpg/189px-Arrhenius2.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/6/6c/Arrhenius2.jpg/252px-Arrhenius2.jpg 2x" width="126"/></a> <div class="thumbcaption"><div class="magnify"><a class="internal" href="/wiki/File:Arrhenius2.jpg" title="Enlarge"></a></div>Svante Arrhenius; believed climate change would take many years</div></div></div>
# <p>As early as the 1820s some scientists were discussing climate change. <a href="/wiki/Joseph_Fourier" title="Joseph Fourier">Joseph Fourier</a> believed that light from the Sun can enter the atmosphere, but cannot leave nearly as easily. He tried to prove that air can absorb the infrared radiation and will be given back to the Earth’s surface. Later in 1859, <a href="/wiki/John_Tyndall" title="John Tyndall">John Tyndall</a> discovered that water vapor and CO<sub>2</sub> trap heat waves given by the sun. In 1896, <a href="/wiki/Svante_Arrhenius" title="Svante Arrhenius">Svante Arrhenius</a> tried to prove that it would take thousands of years for the industrial production of CO<sub>2</sub> to raise the Earth’s temperature 5-6<a href="/wiki/Celsius" title="Celsius">°C</a>.
# </p><p>Throughout the early 20th century few believed this idea. In the mid 20th century, scientists worked out that there was a 10% increase in carbon dioxide in the atmosphere over the 19th century, which made it a bit warmer. It was at this time that people believed the emissions of CO<sub>2</sub> would increase exponentially in the future and the oceans would absorb any surplus of greenhouse gases. In 1956, <a class="new" href="/w/index.php?title=Gilbert_Plass&amp;action=edit&amp;redlink=1" title="Gilbert Plass (not yet started)">Gilbert N. Plass</a> decided that greenhouse gas emissions would have an effect on the Earth’s temperature. He argued that not thinking about GHG emissions would be a mistake. Soon after, scientists studying all different kinds of science began to work together to figure out the mystery of GHG emissions and their effects. As technology advanced, it was in the 1980s that there was proof of a rise in CO<sub>2</sub> levels. An ice core, captured through drilling, provided clear evidence that carbon dioxide levels have risen.<sup class="reference" id="cite_ref-18"><a href="#cite_note-18">[18]</a></sup>
# </p>
# <h2><span class="mw-headline" id="Effects_of_global_warming_on_sea_levels">Effects of global warming on sea levels</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a class="mw-editsection-visualeditor" href="/w/index.php?title=Global_warming&amp;veaction=edit&amp;section=7" title="Change section: Effects of global warming on sea levels">change</a><span class="mw-editsection-divider"> | </span><a href="/w/index.php?title=Global_warming&amp;action=edit&amp;section=7" title="Change section: Effects of global warming on sea levels">change source</a><span class="mw-editsection-bracket">]</span></span></h2>
# <p>Sea level is rising because water over 4 °C (39 °F) <a href="/wiki/Thermal_expansion" title="Thermal expansion">expands when it gets warmer</a>.<sup class="reference" id="cite_ref-Mosher_6-1"><a href="#cite_note-Mosher-6">[6]</a></sup> Probably more important is the melting of ice sheets. The <a href="/wiki/Antarctica" title="Antarctica">Antarctica</a> and <a href="/wiki/Greenland" title="Greenland">Greenland</a> ice sheets are melting. Sea level will rise between half and one metre by 2100, and between 2 and 7 metres by 2300.<sup class="reference" id="cite_ref-19"><a href="#cite_note-19">[19]</a></sup>
# </p><p>Low-lying areas such as <a href="/wiki/Bangladesh" title="Bangladesh">Bangladesh</a>, <a href="/wiki/Florida" title="Florida">Florida</a>, the <a class="mw-redirect" href="/wiki/Netherland" title="Netherland">Netherlands</a> and other areas face massive flooding.<sup class="reference" id="cite_ref-20"><a href="#cite_note-20">[20]</a></sup><sup class="reference" id="cite_ref-21"><a href="#cite_note-21">[21]</a></sup>
# </p>
# <h3><span class="mw-headline" id="Cities_affected_by_current_sea_level_rise">Cities affected by current sea level rise</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a class="mw-editsection-visualeditor" href="/w/index.php?title=Global_warming&amp;veaction=edit&amp;section=8" title="Change section: Cities affected by current sea level rise">change</a><span class="mw-editsection-divider"> | </span><a href="/w/index.php?title=Global_warming&amp;action=edit&amp;section=8" title="Change section: Cities affected by current sea level rise">change source</a><span class="mw-editsection-bracket">]</span></span></h3>
# <p>Many cities are sea <a href="/wiki/Port" title="Port">ports</a> and under threat of flooding if the present sea level rises.
# </p><p>These and the other cities have either started trying to deal with rising sea level and related <a href="/wiki/Storm_surge" title="Storm surge">storm surge</a>, or are discussing this, according to <a href="/wiki/Wikipedia:Reliable_sources" title="Wikipedia:Reliable sources">reliable sources</a>.
# </p>
# <ul><li><a href="/wiki/London" title="London">London</a> <sup class="reference" id="cite_ref-22"><a href="#cite_note-22">[22]</a></sup></li>
# <li><a href="/wiki/New_York_City" title="New York City">New York City</a><sup class="reference" id="cite_ref-23"><a href="#cite_note-23">[23]</a></sup><sup class="reference" id="cite_ref-24"><a href="#cite_note-24">[24]</a></sup><sup class="reference" id="cite_ref-25"><a href="#cite_note-25">[25]</a></sup><sup class="reference" id="cite_ref-ReferenceA_26-0"><a href="#cite_note-ReferenceA-26">[26]</a></sup></li>
# <li><a href="/wiki/Norfolk,_Virginia" title="Norfolk, Virginia">Norfolk, Virginia</a>, in <a href="/wiki/Hampton_Roads" title="Hampton Roads">Hampton Roads</a> area of <a href="/wiki/United_States" title="United States">United States</a> <sup class="reference" id="cite_ref-27"><a href="#cite_note-27">[27]</a></sup><sup class="reference" id="cite_ref-28"><a href="#cite_note-28">[28]</a></sup></li>
# <li><a href="/wiki/Southampton" title="Southampton">Southampton</a> <sup class="reference" id="cite_ref-29"><a href="#cite_note-29">[29]</a></sup></li>
# <li><a href="/wiki/Crisfield,_Maryland" title="Crisfield, Maryland">Crisfield, Maryland</a>, <a href="/wiki/United_States" title="United States">United States</a> <sup class="reference" id="cite_ref-30"><a href="#cite_note-30">[30]</a></sup></li>
# <li><a href="/wiki/Charleston,_South_Carolina" title="Charleston, South Carolina">Charleston, South Carolina</a> <sup class="reference" id="cite_ref-31"><a href="#cite_note-31">[31]</a></sup></li>
# <li><a href="/wiki/Miami" title="Miami">Miami</a>, <a href="/wiki/Florida" title="Florida">Florida</a>, has been listed as "the number-one most vulnerable city worldwide" in terms of potential damage to property from storm-related flooding and sea-level rise.<sup class="reference" id="cite_ref-RS62013_32-0"><a href="#cite_note-RS62013-32">[32]</a></sup><sup class="reference" id="cite_ref-33"><a href="#cite_note-33">[33]</a></sup></li>
# <li><a href="/wiki/Saint_Petersburg" title="Saint Petersburg">Saint Petersburg</a> <sup class="reference" id="cite_ref-34"><a href="#cite_note-34">[34]</a></sup></li>
# <li><a href="/wiki/Sydney" title="Sydney">Sydney</a>, <a href="/wiki/Australia" title="Australia">Australia</a> <sup class="reference" id="cite_ref-abc_35-0"><a href="#cite_note-abc-35">[35]</a></sup></li>
# <li><a href="/wiki/Jakarta" title="Jakarta">Jakarta</a> <sup class="reference" id="cite_ref-36"><a href="#cite_note-36">[36]</a></sup></li>
# <li><a class="new" href="/w/index.php?title=Thatta&amp;action=edit&amp;redlink=1" title="Thatta (not yet started)">Thatta</a> and <a href="/wiki/Badin" title="Badin">Badin</a>, in <a href="/wiki/Sindh" title="Sindh">Sindh</a>, <a href="/wiki/Pakistan" title="Pakistan">Pakistan</a> <sup class="reference" id="cite_ref-37"><a href="#cite_note-37">[37]</a></sup></li>
# <li><a href="/wiki/Mal%C3%A9" title="Malé">Malé</a>, <a href="/wiki/Maldives" title="Maldives">Maldives</a></li>
# <li><a href="/wiki/Mumbai" title="Mumbai">Mumbai</a>, <a href="/wiki/Buenos_Aires" title="Buenos Aires">Buenos Aires</a>, <a href="/wiki/Los_Angeles" title="Los Angeles">Los Angeles</a>, <a href="/wiki/Rio_de_Janeiro" title="Rio de Janeiro">Rio de Janeiro</a> <sup class="reference" id="cite_ref-ReferenceA_26-1"><a href="#cite_note-ReferenceA-26">[26]</a></sup></li></ul>
# <p>All other coastal cities are also in danger.
# </p>
# <h2><span class="mw-headline" id="Further_reading">Further reading</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a class="mw-editsection-visualeditor" href="/w/index.php?title=Global_warming&amp;veaction=edit&amp;section=9" title="Change section: Further reading">change</a><span class="mw-editsection-divider"> | </span><a href="/w/index.php?title=Global_warming&amp;action=edit&amp;section=9" title="Change section: Further reading">change source</a><span class="mw-editsection-bracket">]</span></span></h2>
# <ul><li><a class="external text" href="https://www.natgeokids.com/uk/discover/geography/general-geography/what-is-climate-change/" rel="nofollow"><i>What is climate change</i></a> <a class="mw-redirect" href="/wiki/National_Geographic" title="National Geographic">National Geographic</a> Kids</li>
# <li><a class="external text" href="https://www.bbc.com/news/science-environment-24021772" rel="nofollow"><i>What is climate change? A really simple guide</i></a> <a href="/wiki/BBC" title="BBC">BBC</a></li></ul>
# <h2><span class="mw-headline" id="Related_pages">Related pages</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a class="mw-editsection-visualeditor" href="/w/index.php?title=Global_warming&amp;veaction=edit&amp;section=10" title="Change section: Related pages">change</a><span class="mw-editsection-divider"> | </span><a href="/w/index.php?title=Global_warming&amp;action=edit&amp;section=10" title="Change section: Related pages">change source</a><span class="mw-editsection-bracket">]</span></span></h2>
# <ul><li><a href="/wiki/Climate_change" title="Climate change">Climate change</a></li>
# <li><a href="/wiki/Stern_Review" title="Stern Review">Stern Review</a></li>
# <li><a href="/wiki/Pollution" title="Pollution">Pollution</a></li>
# <li><a href="/wiki/Intergovernmental_Panel_on_Climate_Change" title="Intergovernmental Panel on Climate Change">Intergovernmental Panel on Climate Change</a></li>
# <li><a href="/wiki/Greenhouse_effect" title="Greenhouse effect">Greenhouse effect</a></li></ul>
# <h2><span class="mw-headline" id="References">References</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a class="mw-editsection-visualeditor" href="/w/index.php?title=Global_warming&amp;veaction=edit&amp;section=11" title="Change section: References">change</a><span class="mw-editsection-divider"> | </span><a href="/w/index.php?title=Global_warming&amp;action=edit&amp;section=11" title="Change section: References">change source</a><span class="mw-editsection-bracket">]</span></span></h2>
# <style data-mw-deduplicate="TemplateStyles:r8087918">.mw-parser-output .reflist{font-size:90%;margin-bottom:0.5em;list-style-type:decimal}.mw-parser-output .reflist .references{font-size:100%;margin-bottom:0;list-style-type:inherit}.mw-parser-output .reflist-columns-2{column-width:30em}.mw-parser-output .reflist-columns-3{column-width:25em}.mw-parser-output .reflist-columns{margin-top:0.3em}.mw-parser-output .reflist-columns ol{margin-top:0}.mw-parser-output .reflist-columns li{page-break-inside:avoid;break-inside:avoid-column}.mw-parser-output .reflist-upper-alpha{list-style-type:upper-alpha}.mw-parser-output .reflist-upper-roman{list-style-type:upper-roman}.mw-parser-output .reflist-lower-alpha{list-style-type:lower-alpha}.mw-parser-output .reflist-lower-greek{list-style-type:lower-greek}.mw-parser-output .reflist-lower-roman{list-style-type:lower-roman}</style><div class="reflist">
# <div class="mw-references-wrap mw-references-columns"><ol class="references">
# <li id="cite_note-1"><span class="mw-cite-backlink"><a href="#cite_ref-1">↑</a></span> <span class="reference-text"><style data-mw-deduplicate="TemplateStyles:r7983297">.mw-parser-output cite.citation{font-style:inherit;word-wrap:break-word}.mw-parser-output .citation q{quotes:"\"""\"""'""'"}.mw-parser-output .citation:target{background-color:rgba(0,127,255,0.133)}.mw-parser-output .id-lock-free a,.mw-parser-output .citation .cs1-lock-free a{background:linear-gradient(transparent,transparent),url("//upload.wikimedia.org/wikipedia/commons/6/65/Lock-green.svg")right 0.1em center/9px no-repeat}.mw-parser-output .id-lock-limited a,.mw-parser-output .id-lock-registration a,.mw-parser-output .citation .cs1-lock-limited a,.mw-parser-output .citation .cs1-lock-registration a{background:linear-gradient(transparent,transparent),url("//upload.wikimedia.org/wikipedia/commons/d/d6/Lock-gray-alt-2.svg")right 0.1em center/9px no-repeat}.mw-parser-output .id-lock-subscription a,.mw-parser-output .citation .cs1-lock-subscription a{background:linear-gradient(transparent,transparent),url("//upload.wikimedia.org/wikipedia/commons/a/aa/Lock-red-alt-2.svg")right 0.1em center/9px no-repeat}.mw-parser-output .cs1-ws-icon a{background:linear-gradient(transparent,transparent),url("//upload.wikimedia.org/wikipedia/commons/4/4c/Wikisource-logo.svg")right 0.1em center/12px no-repeat}.mw-parser-output .cs1-code{color:inherit;background:inherit;border:none;padding:inherit}.mw-parser-output .cs1-hidden-error{display:none;color:#d33}.mw-parser-output .cs1-visible-error{color:#d33}.mw-parser-output .cs1-maint{display:none;color:#3a3;margin-left:0.3em}.mw-parser-output .cs1-format{font-size:95%}.mw-parser-output .cs1-kern-left{padding-left:0.2em}.mw-parser-output .cs1-kern-right{padding-right:0.2em}.mw-parser-output .citation .mw-selflink{font-weight:inherit}</style><cite class="citation web cs1"><a class="external text" href="https://www.nationalgeographic.com/environment/global-warming/global-warming-overview/" rel="nofollow">"What Is Global Warming?"</a>. <i>National Geographic</i>. 2019-01-22.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=National+Geographic&amp;rft.atitle=What+Is+Global+Warming%3F&amp;rft.date=2019-01-22&amp;rft_id=https%3A%2F%2Fwww.nationalgeographic.com%2Fenvironment%2Fglobal-warming%2Fglobal-warming-overview%2F&amp;rfr_id=info%3Asid%2Fsimple.wikipedia.org%3AGlobal+warming"></span></span>
# </li>
# ...
# <input name="title" type="hidden" value="Special:Search"/>
# <input class="searchButton mw-fallbackSearchButton" id="mw-searchButton" name="fulltext" title="Search the pages for this text" type="submit" value="Search"/>
# <input class="searchButton" id="searchButton" name="go" title="Go to a page with this exact name if it exists" type="submit" value="Go"/>
# </div>
# </form>
# </div>
# </div>
# </div>
# </div>
# <div id="mw-panel">
# <div id="p-logo" role="banner">
# <a class="mw-wiki-logo" href="/wiki/Main_Page" title="Visit the main page"></a>
# </div>
# <nav aria-labelledby="p-navigation-label" class="mw-portlet mw-portlet-navigation vector-menu vector-menu-portal portal" id="p-navigation" role="navigation">
# <h3 class="vector-menu-heading" id="p-navigation-label">
# <span class="vector-menu-heading-label">Getting around</span>
# </h3>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="mw-list-item" id="n-mainpage-description"><a accesskey="z" href="/wiki/Main_Page" icon="home" title="Visit the main page [z]"><span>Main page</span></a></li><li class="mw-list-item" id="n-portal"><a href="/wiki/Wikipedia:Simple_start" title="About the project, what you can do, where to find things"><span>Simple start</span></a></li><li class="mw-list-item" id="n-Simple-talk"><a href="/wiki/Wikipedia:Simple_talk"><span>Simple talk</span></a></li><li class="mw-list-item" id="n-recentchanges"><a accesskey="r" href="/wiki/Special:RecentChanges" icon="recentChanges" title="The list of new changes in the wiki. [r]"><span>New changes</span></a></li><li class="mw-list-item" id="n-randompage"><a accesskey="x" href="/wiki/Special:Random" icon="die" title="Show any page [x]"><span>Show any page</span></a></li><li class="mw-list-item" id="n-help"><a href="/wiki/Help:Contents" icon="help" title="The place to get help"><span>Help</span></a></li><li class="mw-list-item" id="n-contactpage"><a href="//simple.wikipedia.org/wiki/Wikipedia:Contact_us"><span>Contact us</span></a></li><li class="mw-list-item" id="n-sitesupport"><a href="//donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&amp;utm_medium=sidebar&amp;utm_campaign=C13_simple.wikipedia.org&amp;uselang=en" title="Support us"><span>Give to Wikipedia</span></a></li><li class="mw-list-item" id="n-aboutsite"><a href="/wiki/Wikipedia:About"><span>About Wikipedia</span></a></li></ul>
# </div>
# </nav>
# <nav aria-labelledby="p-tb-label" class="mw-portlet mw-portlet-tb vector-menu vector-menu-portal portal" id="p-tb" role="navigation">
# <h3 class="vector-menu-heading" id="p-tb-label">
# <span class="vector-menu-heading-label">Tools</span>
# </h3>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="mw-list-item" id="t-whatlinkshere"><a accesskey="j" href="/wiki/Special:WhatLinksHere/Global_warming" title="A list of all wiki pages that link here [j]"><span>What links here</span></a></li><li class="mw-list-item" id="t-recentchangeslinked"><a accesskey="k" href="/wiki/Special:RecentChangesLinked/Global_warming" rel="nofollow" title="New changes in pages linked from this page [k]"><span>Related changes</span></a></li><li class="mw-list-item" id="t-upload"><a accesskey="u" href="//commons.wikimedia.org/wiki/Special:UploadWizard" title="Upload files [u]"><span>Upload file</span></a></li><li class="mw-list-item" id="t-specialpages"><a accesskey="q" href="/wiki/Special:SpecialPages" title="A list of all special pages [q]"><span>Special pages</span></a></li><li class="mw-list-item" id="t-permalink"><a href="/w/index.php?title=Global_warming&amp;oldid=8285778" title="Permanent link to this revision of the page"><span>Permanent link</span></a></li><li class="mw-list-item" id="t-info"><a href="/w/index.php?title=Global_warming&amp;action=info" title="More information about this page"><span>Page information</span></a></li><li class="mw-list-item" id="t-cite"><a href="/w/index.php?title=Special:CiteThisPage&amp;page=Global_warming&amp;id=8285778&amp;wpFormIdentifier=titleform" title="Information on how to cite this page"><span>Cite this page</span></a></li><li class="mw-list-item" id="t-wikibase"><a accesskey="g" href="https://www.wikidata.org/wiki/Special:EntityPage/Q7942" title="Link to connected data repository item [g]"><span>Wikidata item</span></a></li></ul>
# </div>
# </nav>
# <nav aria-labelledby="p-coll-print_export-label" class="mw-portlet mw-portlet-coll-print_export vector-menu vector-menu-portal portal" id="p-coll-print_export" role="navigation">
# <h3 class="vector-menu-heading" id="p-coll-print_export-label">
# <span class="vector-menu-heading-label">Print/export</span>
# </h3>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="mw-list-item" id="coll-create_a_book"><a href="/w/index.php?title=Special:Book&amp;bookcmd=book_creator&amp;referer=Global+warming"><span>Make a book</span></a></li><li class="mw-list-item" id="coll-download-as-rl"><a href="/w/index.php?title=Special:DownloadAsPdf&amp;page=Global_warming&amp;action=show-download-screen"><span>Download as PDF</span></a></li><li class="mw-list-item" id="t-print"><a accesskey="p" href="/w/index.php?title=Global_warming&amp;printable=yes" title="Printable version of this page [p]"><span>Page for printing</span></a></li></ul>
# </div>
# </nav>
# <nav aria-labelledby="p-wikibase-otherprojects-label" class="mw-portlet mw-portlet-wikibase-otherprojects vector-menu vector-menu-portal portal" id="p-wikibase-otherprojects" role="navigation">
# <h3 class="vector-menu-heading" id="p-wikibase-otherprojects-label">
# <span class="vector-menu-heading-label">In other projects</span>
# </h3>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="wb-otherproject-link wb-otherproject-commons mw-list-item"><a href="https://commons.wikimedia.org/wiki/Category:Global_warming" hreflang="en"><span>Wikimedia Commons</span></a></li></ul>
# </div>
# </nav>
# <nav aria-labelledby="p-lang-label" class="mw-portlet mw-portlet-lang vector-menu vector-menu-portal portal" id="p-lang" role="navigation">
# <h3 class="vector-menu-heading" id="p-lang-label">
# <span class="vector-menu-heading-label">In other languages</span>
# </h3>
# <div class="vector-menu-content">
# <ul class="vector-menu-content-list"><li class="interlanguage-link interwiki-af badge-Q17437796 badge-featuredarticle mw-list-item" title="featured article badge"><a class="interlanguage-link-target" href="https://af.wikipedia.org/wiki/Aardverwarming" hreflang="af" lang="af" title="Aardverwarming – Afrikaans"><span>Afrikaans</span></a></li><li class="interlanguage-link interwiki-als mw-list-item"><a class="interlanguage-link-target" href="https://als.wikipedia.org/wiki/Globale_Erw%C3%A4rmung" hreflang="gsw" lang="gsw" title="Globale Erwärmung – Alemannisch"><span>Alemannisch</span></a></li><li class="interlanguage-link interwiki-am mw-list-item"><a class="interlanguage-link-target" href="https://am.wikipedia.org/wiki/%E1%8B%A8%E1%8B%93%E1%88%88%E1%88%9D_%E1%88%98%E1%88%9E%E1%89%85" hreflang="am" lang="am" title="የዓለም መሞቅ – Amharic"><span>አማርኛ</span></a></li><li class="interlanguage-link interwiki-ang mw-list-item"><a class="interlanguage-link-target" href="https://ang.wikipedia.org/wiki/Woruldlicu_wearmung" hreflang="ang" lang="ang" title="Woruldlicu wearmung – Old English"><span>Ænglisc</span></a></li><li class="interlanguage-link interwiki-ar mw-list-item"><a class="interlanguage-link-target" href="https://ar.wikipedia.org/wiki/%D8%A7%D9%84%D8%A7%D8%AD%D8%AA%D8%A8%D8%A7%D8%B3_%D8%A7%D9%84%D8%AD%D8%B1%D8%A7%D8%B1%D9%8A" hreflang="ar" lang="ar" title="الاحتباس الحراري – Arabic"><span>العربية</span></a></li><li class="interlanguage-link interwiki-an mw-list-item"><a class="interlanguage-link-target" href="https://an.wikipedia.org/wiki/Escalfamiento_global" hreflang="an" lang="an" title="Escalfamiento global – Aragonese"><span>Aragonés</span></a></li><li class="interlanguage-link interwiki-as mw-list-item"><a class="interlanguage-link-target" href="https://as.wikipedia.org/wiki/%E0%A6%97%E0%A7%8B%E0%A6%B2%E0%A6%95%E0%A7%80%E0%A6%AF%E0%A6%BC_%E0%A6%89%E0%A6%B7%E0%A7%8D%E0%A6%A3%E0%A6%A4%E0%A6%BE_%E0%A6%AC%E0%A7%83%E0%A6%A6%E0%A7%8D%E0%A6%A7%E0%A6%BF" hreflang="as" lang="as" title="গোলকীয় উষ্ণতা বৃদ্ধি – Assamese"><span>অসমীয়া</span></a></li><li class="interlanguage-link interwiki-ast mw-list-item"><a class="interlanguage-link-target" href="https://ast.wikipedia.org/wiki/Calentamientu_global" hreflang="ast" lang="ast" title="Calentamientu global – Asturian"><span>Asturianu</span></a></li><li class="interlanguage-link interwiki-gn mw-list-item"><a class="interlanguage-link-target" href="https://gn.wikipedia.org/wiki/Yvy_%C3%B1embyaku" hreflang="gn" lang="gn" title="Yvy ñembyaku – Guarani"><span>Avañe'ẽ</span></a></li><li class="interlanguage-link interwiki-az mw-list-item"><a class="interlanguage-link-target" href="https://az.wikipedia.org/wiki/%C4%B0qlim_d%C9%99yi%C5%9Fikliyi" hreflang="az" lang="az" title="İqlim dəyişikliyi – Azerbaijani"><span>Azərbaycanca</span></a></li><li class="interlanguage-link interwiki-bn mw-list-item"><a class="interlanguage-link-target" href="https://bn.wikipedia.org/wiki/%E0%A6%AD%E0%A7%82%E0%A6%AE%E0%A6%A3%E0%A7%8D%E0%A6%A1%E0%A6%B2%E0%A7%80%E0%A6%AF%E0%A6%BC_%E0%A6%89%E0%A6%B7%E0%A7%8D%E0%A6%A3%E0%A6%A4%E0%A6%BE_%E0%A6%AC%E0%A7%83%E0%A6%A6%E0%A7%8D%E0%A6%A7%E0%A6%BF" hreflang="bn" lang="bn" title="ভূমণ্ডলীয় উষ্ণতা বৃদ্ধি – Bangla"><span>বাংলা</span></a></li><li class="interlanguage-link interwiki-zh-min-nan mw-list-item"><a class="interlanguage-link-target" href="https://zh-min-nan.wikipedia.org/wiki/T%C4%93-ki%C3%BB_sio-lo%CC%8Dh-h%C3%B2a" hreflang="nan" lang="nan" title="Tē-kiû sio-lo̍h-hòa – Chinese (Min Nan)"><span>Bân-lâm-gú</span></a></li><li class="interlanguage-link interwiki-ba badge-Q17437798 badge-goodarticle mw-list-item" title="good article badge"><a class="interlanguage-link-target" href="https://ba.wikipedia.org/wiki/%D0%93%D0%BB%D0%BE%D0%B1%D0%B0%D0%BB%D1%8C_%D0%B9%D1%8B%D0%BB%D1%8B%D0%BD%D1%8B%D1%83" hreflang="ba" lang="ba" title="Глобаль йылыныу – Bashkir"><span>Башҡортса</span></a></li><li class="interlanguage-link interwiki-be mw-list-item"><a class="interlanguage-link-target" ...
# <div class="after-portlet after-portlet-lang"><span class="wb-langlinks-edit wb-langlinks-link"><a class="wbc-editpage" href="https://www.wikidata.org/wiki/Special:EntityPage/Q7942#sitelinks-wikipedia" title="Edit interlanguage links">Change links</a></span></div>
# </div>
# </nav>
# </div>
# </div>
# <footer class="mw-footer" id="footer" role="contentinfo">
# <ul id="footer-info">
# <li id="footer-info-lastmod"> This page was last changed on 17 June 2022, at 12:49.</li>
# <li id="footer-info-copyright">Text is available under the <a href="//simple.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License">Creative Commons Attribution/Share-Alike License</a> and the <a href="//simple.wikipedia.org/wiki/Wikipedia:Text_of_the_GNU_Free_Documentation_License">GFDL</a>; additional terms may apply. See <a href="//wikimediafoundation.org/wiki/Terms_of_Use">Terms of Use</a> for details.</li>
# </ul>
# <ul id="footer-places">
# <li id="footer-places-privacy"><a class="extiw" href="https://foundation.wikimedia.org/wiki/Privacy_policy" title="wmf:Privacy policy">Privacy policy</a></li>
# <li id="footer-places-about"><a href="/wiki/Wikipedia:About" title="Wikipedia:About">About Wikipedia</a></li>
# <li id="footer-places-disclaimer"><a href="/wiki/Wikipedia:General_disclaimer" title="Wikipedia:General disclaimer">Disclaimers</a></li>
# <li id="footer-places-mobileview"><a class="noprint stopMobileRedirectToggle" href="//simple.m.wikipedia.org/w/index.php?title=Global_warming&amp;mobileaction=toggle_view_mobile">Mobile view</a></li>
# <li id="footer-places-developers"><a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">Developers</a></li>
# <li id="footer-places-statslink"><a href="https://stats.wikimedia.org/#/simple.wikipedia.org">Statistics</a></li>
# <li id="footer-places-cookiestatement"><a href="https://foundation.wikimedia.org/wiki/Cookie_statement">Cookie statement</a></li>
# </ul>
# <ul class="noprint" id="footer-icons">
# <li id="footer-copyrightico"><a href="https://wikimediafoundation.org/"><img alt="Wikimedia Foundation" height="31" loading="lazy" src="/static/images/footer/wikimedia-button.png" srcset="/static/images/footer/wikimedia-button-1.5x.png 1.5x, /static/images/footer/wikimedia-button-2x.png 2x" width="88"/></a></li>
# <li id="footer-poweredbyico"><a href="https://www.mediawiki.org/"><img alt="Powered by MediaWiki" height="31" loading="lazy" src="/static/images/footer/poweredby_mediawiki_88x31.png" srcset="/static/images/footer/poweredby_mediawiki_132x47.png 1.5x, /static/images/footer/poweredby_mediawiki_176x62.png 2x" width="88"/></a></li>
# </ul>
# </footer>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"0.470","walltime":"0.617","ppvisitednodes":{"value":1672,"limit":1000000},"postexpandincludesize":{"value":54423,"limit":2097152},"templateargumentsize":{"value":348,"limit":2097152},"expansiondepth":{"value":8,"limit":100},"expensivefunctioncount":{"value":3,"limit":500},"unstrip-depth":{"value":1,"limit":20},"unstrip-size":{"value":90678,"limit":5000000},"entityaccesscount":{"value":0,"limit":400},"timingprofile":["100.00%  501.428      1 -total"," 63.31%  317.464      1 Template:Reflist"," 39.23%  196.694     21 Template:Cite_web"," 19.68%   98.690      1 Template:About","  6.62%   33.210      6 Template:Convert","  5.41%   27.129      6 Template:Cite_news","  3.70%   18.566      1 Template:Cite_book","  2.72%   13.647      2 Template:Webarchive","  2.15%   10.785      1 Template:Sisterlinks","  1.74%    8.713      1 Template:Harvid"]},"scribunto":{"limitreport-timeusage":{"value":"0.252","limit":"10.000"},"limitreport-memusage":{"value":8519719,"limit":52428800}},"cachereport":{"origin":"mw1380","timestamp":"20220617124908","ttl":1814400,"transientcontent":false}}});});</script>
# <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"Article","name":"Global warming","url":"https:\/\/simple.wikipedia.org\/wiki\/Global_warming","sameAs":"http:\/\/www.wikidata.org\/entity\/Q7942","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q7942","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2005-01-18T21:23:08Z","dateModified":"2022-06-17T12:49:04Z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/commons\/a\/a0\/20200324_Global_average_temperature_-_NASA-GISS_HadCrut_NOAA_Japan_BerkeleyE.svg","headline":"current rise in Earth's average temperature and related large-scale shifts in weather patterns"}</script><script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"Article","name":"Global warming","url":"https:\/\/simple.wikipedia.org\/wiki\/Global_warming","sameAs":"http:\/\/www.wikidata.org\/entity\/Q7942","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q7942","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2005-01-18T21:23:08Z","dateModified":"2022-06-17T12:49:04Z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/commons\/a\/a0\/20200324_Global_average_temperature_-_NASA-GISS_HadCrut_NOAA_Japan_BerkeleyE.svg","headline":"current rise in Earth's average temperature and related large-scale shifts in weather patterns"}</script>
# <script>(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":167,"wgHostname":"mw1387"});});</script>
# </body>
# </html>

# %%
text = ""
for paragraph in soup.find_all('p'):
    text += paragraph.text

# %%
text
# Out:
# "Global warming is the current rise in temperature of the air and oceans. It happens because humans burn coal, oil and natural gas, and cut down forests.[1] Average temperatures today are about 1\xa0°C (1.8\xa0°F) higher than before people started burning a lot of coal around 1750.[2] In some parts of the world it is less and some more. Most climate scientists say that by the year 2100 temperatures will be 2\xa0°C (3.6\xa0°F) to  4\xa0°C (7.2\xa0°F) higher than they were before 1750.[3] The extra warmth melts ice caps around the world. Sea level is rising for two reasons: ice on the land, like Greenland, melts into the sea. Water also gets larger when it warms. Many cities will be partly flooded by the ocean in the 21st century.\nGlobal warming is mostly because of people burning things, like gasoline for cars and natural gas to keep houses warm. But the heat from the burning itself only makes the world a tiny bit warmer: it is the carbon dioxide from the burning which is the biggest part of the problem. Among the greenhouse gases, the increase of carbon dioxide in the atmosphere is the main cause of global warming, as predicted by Svante Arrhenius a hundred years ago, confirming the work of Joseph Fourier more than 200 years ago. When people burn fossil fuels like coal, oil and natural gas this adds carbon dioxide into the air.[4] This is because fossil fuels contain lots of carbon and burning means joining most of the atoms in the fuel with oxygen. When people cut down many trees (deforestation), this means less carbon dioxide is taken out of the atmosphere by those plants. The gas produced by cows digestion also causes global warming, because it contains a greenhouse gas called methane.[5]\nAs the Earth's surface temperature becomes hotter the sea level rises. This is partly because water over 4\xa0°C (39\xa0°F) expands when it gets warmer.[6] It is also partly because warm temperatures make glaciers and ice caps melt. The sea level rise causes coastal areas to flood.[7] Weather patterns, including where and how much rain or snow there is, are changing. Deserts will probably increase in size. Colder areas will warm up faster than warm areas. Strong storms may become more likely and farming may not make as much food. These effects will not be the same everywhere. The changes from one area to another are not well known.\nGovernments have agreed to keep temperature rise below 2\xa0°C (3.6\xa0°F), but current plans by governments are not enough to limit global warming that much.[8]\nPeople in government and the Intergovernmental Panel on Climate Change (IPCC) are talking about global warming. But governments, companies, and other people do not agree on what to do about it. Some things that could reduce warming are to burn less fossil fuels, grow more trees, eat less meat, and put some carbon dioxide back in the ground. People could adapt to some temperature change. The Kyoto Protocol and Paris Agreement try to reduce pollution from the burning of fossil fuels. Most governments have agreed to them but some people in government think nothing should change. \nClimate change has happened constantly over the history of the Earth, including the coming and going of ice ages. But modern climate change is different because people are putting carbon dioxide into the atmosphere very quickly.[9]\nSince the 1800s, people have recorded the daily temperature. By about 1850, there were enough places measuring temperature so that scientists could know the global average temperature. Compared with before people started burning a lot of coal for industry, the temperature has risen by about 1\xa0°C (1.8\xa0°F).[2] In 1979, satellites started measuring the temperature of the Earth.[10]\nBefore 1850, there were not enough temperature measurements for us to know how warm or cold it was. Climatologists use proxy measurements to try to figure out past temperatures before there were thermometers. This means measuring things that change when it gets cold ...

# %%
import re

# %%
text = re.sub(r'\[[0-9]*\]',' ',text)
text = text.lower()
text = re.sub(r'\s+',' ',text)
clean_text = re.sub(r'\W',' ',text)
clean_text = re.sub(r'\d',' ',clean_text)
clean_text = re.sub(r'\s+[a-z]\s+',' ',clean_text)
clean_text = re.sub(r'\s+',' ',clean_text)
clean_text = re.sub(r'\s+$','',clean_text)

# %%
clean_text
# Out:
# 'global warming is the current rise in temperature of the air and oceans it happens because humans burn coal oil and natural gas and cut down forests average temperatures today are about f higher than before people started burning lot of coal around in some parts of the world it is less and some more most climate scientists say that by the year temperatures will be f to f higher than they were before the extra warmth melts ice caps around the world sea level is rising for two reasons ice on the land like greenland melts into the sea water also gets larger when it warms many cities will be partly flooded by the ocean in the st century global warming is mostly because of people burning things like gasoline for cars and natural gas to keep houses warm but the heat from the burning itself only makes the world tiny bit warmer it is the carbon dioxide from the burning which is the biggest part of the problem among the greenhouse gases the increase of carbon dioxide in the atmosphere is the main cause of global warming as predicted by svante arrhenius hundred years ago confirming the work of joseph fourier more than years ago when people burn fossil fuels like coal oil and natural gas this adds carbon dioxide into the air this is because fossil fuels contain lots of carbon and burning means joining most of the atoms in the fuel with oxygen when people cut down many trees deforestation this means less carbon dioxide is taken out of the atmosphere by those plants the gas produced by cows digestion also causes global warming because it contains greenhouse gas called methane as the earth surface temperature becomes hotter the sea level rises this is partly because water over f expands when it gets warmer it is also partly because warm temperatures make glaciers and ice caps melt the sea level rise causes coastal areas to flood weather patterns including where and how much rain or snow there is are changing deserts will probably increase in size colder areas will warm up faster than warm areas strong storms may become more likely and farming may not make as much food these effects will not be the same everywhere the changes from one area to another are not well known governments have agreed to keep temperature rise below f but current plans by governments are not enough to limit global warming that much people in government and the intergovernmental panel on climate change ipcc are talking about global warming but governments companies and other people do not agree on what to do about it some things that could reduce warming are to burn less fossil fuels grow more trees eat less meat and put some carbon dioxide back in the ground people could adapt to some temperature change the kyoto protocol and paris agreement try to reduce pollution from the burning of fossil fuels most governments have agreed to them but some people in government think nothing should change climate change has happened constantly over the history of the earth including the coming and going of ice ages but modern climate change is different because people are putting carbon dioxide into the atmosphere very quickly since the people have recorded the daily temperature by about there were enough places measuring temperature so that scientists could know the global average temperature compared with before people started burning lot of coal for industry the temperature has risen by about f in satellites started measuring the temperature of the earth before there were not enough temperature measurements for us to know how warm or cold it was climatologists use proxy measurements to try to figure out past temperatures before there were thermometers this means measuring things that change when it gets colder or warmer one way is to cut into tree and measure how far apart the growth rings are trees that live long time can give us an idea of how temperature and rain changed while they were alive for most of the past years the average temperature of the world didn change much the ...

# %%
import nltk
sentences = nltk.sent_tokenize(text)

# %%
sentences
# Out:
# ['global warming is the current rise in temperature of the air and oceans.',
#  'it happens because humans burn coal, oil and natural gas, and cut down forests.',
#  'average temperatures today are about 1 °c (1.8 °f) higher than before people started burning a lot of coal around 1750. in some parts of the world it is less and some more.',
#  'most climate scientists say that by the year 2100 temperatures will be 2 °c (3.6 °f) to 4 °c (7.2 °f) higher than they were before 1750. the extra warmth melts ice caps around the world.',
#  'sea level is rising for two reasons: ice on the land, like greenland, melts into the sea.',
#  'water also gets larger when it warms.',
#  'many cities will be partly flooded by the ocean in the 21st century.',
#  'global warming is mostly because of people burning things, like gasoline for cars and natural gas to keep houses warm.',
#  'but the heat from the burning itself only makes the world a tiny bit warmer: it is the carbon dioxide from the burning which is the biggest part of the problem.',
#  'among the greenhouse gases, the increase of carbon dioxide in the atmosphere is the main cause of global warming, as predicted by svante arrhenius a hundred years ago, confirming the work of joseph fourier more than 200 years ago.',
#  'when people burn fossil fuels like coal, oil and natural gas this adds carbon dioxide into the air.',
#  'this is because fossil fuels contain lots of carbon and burning means joining most of the atoms in the fuel with oxygen.',
#  'when people cut down many trees (deforestation), this means less carbon dioxide is taken out of the atmosphere by those plants.',
#  'the gas produced by cows digestion also causes global warming, because it contains a greenhouse gas called methane.',
#  "as the earth's surface temperature becomes hotter the sea level rises.",
#  'this is partly because water over 4 °c (39 °f) expands when it gets warmer.',
#  'it is also partly because warm temperatures make glaciers and ice caps melt.',
#  'the sea level rise causes coastal areas to flood.',
#  'weather patterns, including where and how much rain or snow there is, are changing.',
#  'deserts will probably increase in size.',
#  'colder areas will warm up faster than warm areas.',
#  'strong storms may become more likely and farming may not make as much food.',
#  'these effects will not be the same everywhere.',
#  'the changes from one area to another are not well known.',
#  'governments have agreed to keep temperature rise below 2 °c (3.6 °f), but current plans by governments are not enough to limit global warming that much.',
#  'people in government and the intergovernmental panel on climate change (ipcc) are talking about global warming.',
#  'but governments, companies, and other people do not agree on what to do about it.',
#  'some things that could reduce warming are to burn less fossil fuels, grow more trees, eat less meat, and put some carbon dioxide back in the ground.',
#  'people could adapt to some temperature change.',
#  'the kyoto protocol and paris agreement try to reduce pollution from the burning of fossil fuels.',
#  'most governments have agreed to them but some people in government think nothing should change.',
#  'climate change has happened constantly over the history of the earth, including the coming and going of ice ages.',
#  'but modern climate change is different because people are putting carbon dioxide into the atmosphere very quickly.',
#  'since the 1800s, people have recorded the daily temperature.',
#  'by about 1850, there were enough places measuring temperature so that scientists could know the global average temperature.',
#  'compared with before people started burning a lot of coal for industry, the temperature has risen by about 1 °c (1.8 °f).',
#  'in 1979, satellites started measuring the temperature of the earth.',
#  'before 1850, there were not enough temperature measurements for us to know how warm or cold it was.',
#  'climatologists use proxy measurements to try to figure out past temperatures before there were thermometers.',
#  'this means measuring things that change when it gets colder or warmer.',
#  'one way is to cut into a tree and measure how far apart the growth rings are.',
#  'trees that live a long time can give us an idea of how temperature and rain changed while they were alive.',
#  "for most of the past 2000 years the average temperature of the world didn't change much.",
#  'there were some times where the temperatures were a little warmer or cooler in some places.',
#  'one of the most famous warm times was the medieval warm period and one of the most famous cool times was the little ice age (not really an ice age).',
#  'other proxy measurements like the temperature measured in deep holes mostly agree with the tree rings.',
#  'tree rings and bore holes can only help scientists work out the temperature back to about 2000 years ago.',
#  'ice cores are also used to find out the temperature back to about half a million years ago.',
#  'there a many greenhouse gases that cause the earth to warm.',
#  'the most important one is carbon dioxide (co2).',
#  'co2 comes from power plants, where coal and natural gas are burnt.',
#  'cars also emit co2 when they burn petrol.',
#  "about 23 billion tons of carbon dioxide and other greenhouse gases are released into the earth's atmosphere each year.",
#  'the amount of co2 in the air is about 48% more than it was around 1750. about three-quarters of the co2 that people have put in the air during the past 20 years are due to burning fossil fuel like coal or oil.',
#  'the rest mostly comes from changes in how land is used, like cutting down trees.',
#  'the second most important greenhouse gas is methane.',
#  'this comes mostly from food production.',
#  'some methane also leaks when oil and gas are produced.',
#  'dust and dirt in the air may come from natural sources such as volcanos, erosion and meteoric dust.',
#  'some of this dirt falls out within a few hours.',
#  'some is aerosol, so small that it could stay in the air for years.',
#  'the aerosol particles in the atmosphere make the earth colder.',
#  'the effect of dust therefore cancels out some of the effects of greenhouse gases.',
#  'even though humans also put aerosols in the air when they burn coal or oil this only cancels out the greenhouse effect of the fuel burning for less than 20 years: however the carbon dioxide stays in the atmosphere much longer and keeps on warming the earth.',
#  'some people burn less fossil fuel.',
#  'countries try to emit less greenhouse gases.',
#  'the kyoto protocol was signed in 1997. it was meant to reduce the amount of greenhouse gases in the atmosphere to below their levels in 1990. however, carbon dioxide levels have continued to rise.',
#  'energy conservation is used to burn less fossil fuel.',
#  "people can also use energy sources that don't burn fossil fuel, like solar panels or electricity from nuclear power or wind power.",
#  'or they can prevent the carbon dioxide from getting out into the atmosphere, which is called carbon capture and storage (ccs).',
#  'people can change how they live because of the effect of climate change.',
#  'for example, they can go to places where the weather is better, or build walls around cities to keep flood water out.',
#  'this cost money, and rich people and rich countries will be able to change more easily than the poor.',
#  'as early as the 1820s some scientists were discussing climate change.',
#  'joseph fourier believed that light from the sun can enter the atmosphere, but cannot leave nearly as easily.',
#  'he tried to prove that air can absorb the infrared radiation and will be given back to the earth’s surface.',
#  'later in 1859, john tyndall discovered that water vapor and co2 trap heat waves given by the sun.',
#  'in 1896, svante arrhenius tried to prove that it would take thousands of years for the industrial production of co2 to raise the earth’s temperature 5-6°c.',
#  'throughout the early 20th century few believed this idea.',
#  'in the mid 20th century, scientists worked out that there was a 10% increase in carbon dioxide in the atmosphere over the 19th century, which made it a bit warmer.',
#  'it was at this time that people believed the emissions of co2 would increase exponentially in the future and the oceans would absorb any surplus of greenhouse gases.',
#  'in 1956, gilbert n. plass decided that greenhouse gas emissions would have an effect on the earth’s temperature.',
#  'he argued that not thinking about ghg emissions would be a mistake.',
#  'soon after, scientists studying all different kinds of science began to work together to figure out the mystery of ghg emissions and their effects.',
#  'as technology advanced, it was in the 1980s that there was proof of a rise in co2 levels.',
#  'an ice core, captured through drilling, provided clear evidence that carbon dioxide levels have risen.',
#  'sea level is rising because water over 4 °c (39 °f) expands when it gets warmer.',
#  'probably more important is the melting of ice sheets.',
#  'the antarctica and greenland ice sheets are melting.',
#  'sea level will rise between half and one metre by 2100, and between 2 and 7 metres by 2300. low-lying areas such as bangladesh, florida, the netherlands and other areas face massive flooding.',
#  'many cities are sea ports and under threat of flooding if the present sea level rises.',
#  'these and the other cities have either started trying to deal with rising sea level and related storm surge, or are discussing this, according to reliable sources.',
#  'all other coastal cities are also in danger.']

# %%
len(sentences)
# Out:
# 93

# %%
stop_words = nltk.corpus.stopwords.words('english')

# %%
stop_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
len(stop_words)
# Out:
# 179

# %%
word2count = {}
for word in nltk.word_tokenize(clean_text):
    if word not in stop_words:
        if word not in word2count.keys():
            word2count[word] = 1
        else:
            word2count[word] +=1

# %%
word2count
# Out:
# {'global': 7,
#  'warming': 8,
#  'current': 2,
#  'rise': 6,
#  'temperature': 17,
#  'air': 8,
#  'oceans': 2,
#  'happens': 1,
#  'humans': 2,
#  'burn': 8,
#  'coal': 7,
#  'oil': 5,
#  'natural': 5,
#  'gas': 9,
#  'cut': 3,
#  'forests': 1,
#  'average': 3,
#  'temperatures': 5,
#  'today': 1,
#  'f': 7,
#  'higher': 2,
#  'people': 17,
#  'started': 4,
#  'burning': 9,
#  'lot': 2,
#  'around': 4,
#  'parts': 1,
#  'world': 4,
#  'less': 8,
#  'climate': 6,
#  'scientists': 6,
#  'say': 1,
#  'year': 2,
#  'extra': 1,
#  'warmth': 1,
#  'melts': 2,
#  'ice': 10,
#  'caps': 2,
#  'sea': 9,
#  'level': 7,
#  'rising': 3,
#  'two': 1,
#  'reasons': 1,
#  'land': 2,
#  'like': 7,
#  'greenland': 2,
#  'water': 5,
#  'also': 9,
#  'gets': 4,
#  'larger': 1,
#  'warms': 1,
#  'many': 4,
#  'cities': 5,
#  'partly': 3,
#  'flooded': 1,
#  'ocean': 1,
#  'st': 1,
#  'century': 4,
#  'mostly': 4,
#  'things': 3,
#  'gasoline': 1,
#  'cars': 2,
#  'keep': 3,
#  'houses': 1,
#  'warm': 8,
#  'heat': 2,
#  'makes': 1,
#  'tiny': 1,
#  'bit': 2,
#  'warmer': 6,
#  'carbon': 15,
#  'dioxide': 13,
#  'biggest': 1,
#  'part': 1,
#  'problem': 1,
#  'among': 1,
#  'greenhouse': 11,
#  'gases': 7,
#  'increase': 4,
#  'atmosphere': 10,
#  'main': 1,
#  'cause': 2,
#  'predicted': 1,
#  'svante': 2,
#  'arrhenius': 2,
#  'hundred': 1,
#  'years': 9,
#  'ago': 4,
#  'confirming': 1,
#  'work': 3,
#  'joseph': 2,
#  'fourier': 2,
#  'fossil': 8,
#  'fuels': 4,
#  'adds': 1,
#  'contain': 1,
#  'lots': 1,
#  'means': 3,
#  'joining': 1,
#  'atoms': 1,
#  'fuel': 6,
#  'oxygen': 1,
#  'trees': 4,
#  'deforestation': 1,
#  'taken': 1,
#  'plants': 2,
#  'produced': 2,
#  'cows': 1,
#  'digestion': 1,
#  'causes': 2,
#  'contains': 1,
#  'called': 2,
#  'methane': 3,
#  'earth': 10,
#  'surface': 2,
#  'becomes': 1,
#  'hotter': 1,
#  'rises': 2,
#  'expands': 2,
#  'make': 3,
#  'glaciers': 1,
#  'melt': 1,
#  'coastal': 2,
#  'areas': 5,
#  'flood': 2,
#  'weather': 2,
#  'patterns': 1,
#  'including': 2,
#  'much': 5,
#  'rain': 2,
#  'snow': 1,
#  'changing': 1,
#  'deserts': 1,
#  'probably': 2,
#  'size': 1,
#  'colder': 3,
#  'faster': 1,
#  'strong': 1,
#  'storms': 1,
#  'may': 3,
#  'become': 1,
#  'likely': 1,
#  'farming': 1,
#  'food': 2,
#  'effects': 3,
#  'everywhere': 1,
#  'changes': 2,
#  'one': 6,
#  'area': 1,
#  'another': 1,
#  'well': 1,
#  'known': 1,
#  'governments': 4,
#  'agreed': 2,
#  'plans': 1,
#  'enough': 3,
#  'limit': 1,
#  'government': 2,
#  'intergovernmental': 1,
#  'panel': 1,
#  'change': 11,
#  'ipcc': 1,
#  'talking': 1,
#  'companies': 1,
#  'agree': 2,
#  'could': 4,
#  'reduce': 3,
#  'grow': 1,
#  'eat': 1,
#  'meat': 1,
#  'put': 3,
#  'back': 4,
#  'ground': 1,
#  'adapt': 1,
#  'kyoto': 2,
#  'protocol': 2,
#  'paris': 1,
#  'agreement': 1,
#  'try': 3,
#  'pollution': 1,
#  'think': 1,
#  'nothing': 1,
#  'happened': 1,
#  'constantly': 1,
#  'history': 1,
#  'coming': 1,
#  'going': 1,
#  'ages': 1,
#  'modern': 1,
#  'different': 2,
#  'putting': 1,
#  'quickly': 1,
#  'since': 1,
#  'recorded': 1,
#  'daily': 1,
#  'places': 3,
#  'measuring': 3,
#  'know': 2,
#  'compared': 1,
#  'industry': 1,
#  'risen': 2,
#  'satellites': 1,
#  'measurements': 3,
#  'us': 2,
#  'cold': 1,
#  'climatologists': 1,
#  'use': 2,
#  'proxy': 2,
#  'figure': 2,
#  'past': 3,
#  'thermometers': 1,
#  'way': 1,
#  'tree': 3,
#  'measure': 1,
#  'far': 1,
#  'apart': 1,
#  'growth': 1,
#  'rings': 3,
#  'live': 2,
#  'long': 1,
#  'time': 2,
#  'give': 1,
#  'idea': 2,
#  'changed': 1,
#  'alive': 1,
#  'times': 3,
#  'little': 2,
#  'cooler': 1,
#  'famous': 2,
#  'medieval': 1,
#  'period': 1,
#  'cool': 1,
#  'age': 2,
#  'really': 1,
#  'measured': 1,
#  'deep': 1,
#  'holes': 2,
#  'bore': 1,
#  'help': 1,
#  'cores': 1,
#  'used': 3,
#  'find': 1,
#  'half': 2,
#  'million': 1,
#  'important': 3,
#  'co': 9,
#  'comes': 3,
#  'power': 3,
#  'burnt': 1,
#  'emit': 2,
#  'petrol': 1,
#  'billion': 1,
#  'tons': 1,
#  'released': 1,
#  'amount': 2,
#  'three': 1,
#  'quarters': 1,
#  'due': 1,
#  'rest': 1,
#  'cutting': 1,
#  'second': 1,
#  'production': 2,
#  'leaks': 1,
#  'dust': 3,
#  'dirt': 2,
#  'come': 1,
#  'sources': 3,
#  'volcanos': 1,
#  'erosion': 1,
#  'meteoric': 1,
#  'falls': 1,
#  'within': 1,
#  'hours': 1,
#  'aerosol': 2,
#  'small': 1,
#  'stay': 1,
#  'particles': 1,
#  'effect': 4,
#  'therefore': 1,
#  'cancels': 2,
#  'even': 1,
#  'though': 1,
#  'aerosols': 1,
#  'however': 2,
#  'stays': 1,
#  'longer': 1,
#  'keeps': 1,
#  'countries': 2,
#  'signed': 1,
#  'meant': 1,
#  'levels': 4,
#  'continued': 1,
#  'energy': 2,
#  'conservation': 1,
#  'solar': 1,
#  'panels': 1,
#  'electricity': 1,
#  'nuclear': 1,
#  'wind': 1,
#  'prevent': 1,
#  'getting': 1,
#  'capture': 1,
#  'storage': 1,
#  'ccs': 1,
#  'example': 1,
#  'go': 1,
#  'better': 1,
#  'build': 1,
#  'walls': 1,
#  'cost': 1,
#  'money': 1,
#  'rich': 2,
#  'able': 1,
#  'easily': 2,
#  'poor': 1,
#  'early': 2,
#  'discussing': 2,
#  'believed': 3,
#  'light': 1,
#  'sun': 2,
#  'enter': 1,
#  'leave': 1,
#  'nearly': 1,
#  'tried': 2,
#  'prove': 2,
#  'absorb': 2,
#  'infrared': 1,
#  'radiation': 1,
#  'given': 2,
#  'later': 1,
#  'john': 1,
#  'tyndall': 1,
#  'discovered': 1,
#  'vapor': 1,
#  'trap': 1,
#  'waves': 1,
#  'would': 5,
#  'take': 1,
#  'thousands': 1,
#  'industrial': 1,
#  'raise': 1,
#  'throughout': 1,
#  'th': 3,
#  'mid': 1,
#  'worked': 1,
#  'made': 1,
#  'emissions': 4,
#  'exponentially': 1,
#  'future': 1,
#  'surplus': 1,
#  'gilbert': 1,
#  'plass': 1,
#  'decided': 1,
#  'argued': 1,
#  'thinking': 1,
#  'ghg': 2,
#  'mistake': 1,
#  'soon': 1,
#  'studying': 1,
#  'kinds': 1,
#  'science': 1,
#  'began': 1,
#  'together': 1,
#  'mystery': 1,
#  'technology': 1,
#  'advanced': 1,
#  'proof': 1,
#  'core': 1,
#  'captured': 1,
#  'drilling': 1,
#  'provided': 1,
#  'clear': 1,
#  'evidence': 1,
#  'melting': 2,
#  'sheets': 2,
#  'antarctica': 1,
#  'metre': 1,
#  'metres': 1,
#  'low': 1,
#  'lying': 1,
#  'bangladesh': 1,
#  'florida': 1,
#  'netherlands': 1,
#  'face': 1,
#  'massive': 1,
#  'flooding': 2,
#  'ports': 1,
#  'threat': 1,
#  'present': 1,
#  'either': 1,
#  'trying': 1,
#  'deal': 1,
#  'related': 1,
#  'storm': 1,
#  'surge': 1,
#  'according': 1,
#  'reliable': 1,
#  'danger': 1}

# %%
for key in word2count.keys():
    word2count[key] = word2count[key]/max(word2count.values())

# %%
word2count
# Out:
# {'global': 0.4117647058823529,
#  'warming': 0.47058823529411764,
#  'current': 0.11764705882352941,
#  'rise': 0.35294117647058826,
#  'temperature': 1.0,
#  'air': 0.47058823529411764,
#  'oceans': 0.11764705882352941,
#  'happens': 0.058823529411764705,
#  'humans': 0.11764705882352941,
#  'burn': 0.47058823529411764,
#  'coal': 0.4117647058823529,
#  'oil': 0.29411764705882354,
#  'natural': 0.29411764705882354,
#  'gas': 0.5294117647058824,
#  'cut': 0.17647058823529413,
#  'forests': 0.058823529411764705,
#  'average': 0.17647058823529413,
#  'temperatures': 0.29411764705882354,
#  'today': 0.058823529411764705,
#  'f': 0.4117647058823529,
#  'higher': 0.11764705882352941,
#  'people': 1.0,
#  'started': 0.26666666666666666,
#  'burning': 0.6,
#  'lot': 0.13333333333333333,
#  'around': 0.26666666666666666,
#  'parts': 0.06666666666666667,
#  'world': 0.26666666666666666,
#  'less': 0.5333333333333333,
#  'climate': 0.4,
#  'scientists': 0.4,
#  'say': 0.06666666666666667,
#  'year': 0.13333333333333333,
#  'extra': 0.06666666666666667,
#  'warmth': 0.06666666666666667,
#  'melts': 0.13333333333333333,
#  'ice': 0.6666666666666666,
#  'caps': 0.13333333333333333,
#  'sea': 0.6,
#  'level': 0.4666666666666667,
#  'rising': 0.2,
#  'two': 0.06666666666666667,
#  'reasons': 0.06666666666666667,
#  'land': 0.13333333333333333,
#  'like': 0.4666666666666667,
#  'greenland': 0.13333333333333333,
#  'water': 0.3333333333333333,
#  'also': 0.6,
#  'gets': 0.26666666666666666,
#  'larger': 0.06666666666666667,
#  'warms': 0.06666666666666667,
#  'many': 0.26666666666666666,
#  'cities': 0.3333333333333333,
#  'partly': 0.2,
#  'flooded': 0.06666666666666667,
#  'ocean': 0.06666666666666667,
#  'st': 0.06666666666666667,
#  'century': 0.26666666666666666,
#  'mostly': 0.26666666666666666,
#  'things': 0.2,
#  'gasoline': 0.06666666666666667,
#  'cars': 0.13333333333333333,
#  'keep': 0.2,
#  'houses': 0.06666666666666667,
#  'warm': 0.5333333333333333,
#  'heat': 0.13333333333333333,
#  'makes': 0.06666666666666667,
#  'tiny': 0.06666666666666667,
#  'bit': 0.13333333333333333,
#  'warmer': 0.4,
#  'carbon': 1.0,
#  'dioxide': 1.0,
#  'biggest': 0.09090909090909091,
#  'part': 0.09090909090909091,
#  'problem': 0.09090909090909091,
#  'among': 0.09090909090909091,
#  'greenhouse': 1.0,
#  'gases': 0.6363636363636364,
#  'increase': 0.36363636363636365,
#  'atmosphere': 0.9090909090909091,
#  'main': 0.09090909090909091,
#  'cause': 0.18181818181818182,
#  'predicted': 0.09090909090909091,
#  'svante': 0.18181818181818182,
#  'arrhenius': 0.18181818181818182,
#  'hundred': 0.09090909090909091,
#  'years': 0.8181818181818182,
#  'ago': 0.36363636363636365,
#  'confirming': 0.09090909090909091,
#  'work': 0.2727272727272727,
#  'joseph': 0.18181818181818182,
#  'fourier': 0.18181818181818182,
#  'fossil': 0.7272727272727273,
#  'fuels': 0.36363636363636365,
#  'adds': 0.09090909090909091,
#  'contain': 0.09090909090909091,
#  'lots': 0.09090909090909091,
#  'means': 0.2727272727272727,
#  'joining': 0.09090909090909091,
#  'atoms': 0.09090909090909091,
#  'fuel': 0.5454545454545454,
#  'oxygen': 0.09090909090909091,
#  'trees': 0.36363636363636365,
#  'deforestation': 0.09090909090909091,
#  'taken': 0.09090909090909091,
#  'plants': 0.18181818181818182,
#  'produced': 0.18181818181818182,
#  'cows': 0.09090909090909091,
#  'digestion': 0.09090909090909091,
#  'causes': 0.18181818181818182,
#  'contains': 0.09090909090909091,
#  'called': 0.18181818181818182,
#  'methane': 0.2727272727272727,
#  'earth': 0.9090909090909091,
#  'surface': 0.18181818181818182,
#  'becomes': 0.09090909090909091,
#  'hotter': 0.09090909090909091,
#  'rises': 0.18181818181818182,
#  'expands': 0.18181818181818182,
#  'make': 0.2727272727272727,
#  'glaciers': 0.09090909090909091,
#  'melt': 0.09090909090909091,
#  'coastal': 0.18181818181818182,
#  'areas': 0.45454545454545453,
#  'flood': 0.18181818181818182,
#  'weather': 0.18181818181818182,
#  'patterns': 0.09090909090909091,
#  'including': 0.18181818181818182,
#  'much': 0.45454545454545453,
#  'rain': 0.18181818181818182,
#  'snow': 0.09090909090909091,
#  'changing': 0.09090909090909091,
#  'deserts': 0.09090909090909091,
#  'probably': 0.18181818181818182,
#  'size': 0.09090909090909091,
#  'colder': 0.2727272727272727,
#  'faster': 0.09090909090909091,
#  'strong': 0.09090909090909091,
#  'storms': 0.09090909090909091,
#  'may': 0.2727272727272727,
#  'become': 0.09090909090909091,
#  'likely': 0.09090909090909091,
#  'farming': 0.09090909090909091,
#  'food': 0.18181818181818182,
#  'effects': 0.2727272727272727,
#  'everywhere': 0.09090909090909091,
#  'changes': 0.18181818181818182,
#  'one': 0.5454545454545454,
#  'area': 0.09090909090909091,
#  'another': 0.09090909090909091,
#  'well': 0.09090909090909091,
#  'known': 0.09090909090909091,
#  'governments': 0.36363636363636365,
#  'agreed': 0.18181818181818182,
#  'plans': 0.09090909090909091,
#  'enough': 0.2727272727272727,
#  'limit': 0.09090909090909091,
#  'government': 0.18181818181818182,
#  'intergovernmental': 0.09090909090909091,
#  'panel': 0.09090909090909091,
#  'change': 1.0,
#  'ipcc': 0.1111111111111111,
#  'talking': 0.1111111111111111,
#  'companies': 0.1111111111111111,
#  'agree': 0.2222222222222222,
#  'could': 0.4444444444444444,
#  'reduce': 0.3333333333333333,
#  'grow': 0.1111111111111111,
#  'eat': 0.1111111111111111,
#  'meat': 0.1111111111111111,
#  'put': 0.3333333333333333,
#  'back': 0.4444444444444444,
#  'ground': 0.1111111111111111,
#  'adapt': 0.1111111111111111,
#  'kyoto': 0.2222222222222222,
#  'protocol': 0.2222222222222222,
#  'paris': 0.1111111111111111,
#  'agreement': 0.1111111111111111,
#  'try': 0.3333333333333333,
#  'pollution': 0.1111111111111111,
#  'think': 0.1111111111111111,
#  'nothing': 0.1111111111111111,
#  'happened': 0.1111111111111111,
#  'constantly': 0.1111111111111111,
#  'history': 0.1111111111111111,
#  'coming': 0.1111111111111111,
#  'going': 0.1111111111111111,
#  'ages': 0.1111111111111111,
#  'modern': 0.1111111111111111,
#  'different': 0.2222222222222222,
#  'putting': 0.1111111111111111,
#  'quickly': 0.1111111111111111,
#  'since': 0.1111111111111111,
#  'recorded': 0.1111111111111111,
#  'daily': 0.1111111111111111,
#  'places': 0.3333333333333333,
#  'measuring': 0.3333333333333333,
#  'know': 0.2222222222222222,
#  'compared': 0.1111111111111111,
#  'industry': 0.1111111111111111,
#  'risen': 0.2222222222222222,
#  'satellites': 0.1111111111111111,
#  'measurements': 0.3333333333333333,
#  'us': 0.2222222222222222,
#  'cold': 0.1111111111111111,
#  'climatologists': 0.1111111111111111,
#  'use': 0.2222222222222222,
#  'proxy': 0.2222222222222222,
#  'figure': 0.2222222222222222,
#  'past': 0.3333333333333333,
#  'thermometers': 0.1111111111111111,
#  'way': 0.1111111111111111,
#  'tree': 0.3333333333333333,
#  'measure': 0.1111111111111111,
#  'far': 0.1111111111111111,
#  'apart': 0.1111111111111111,
#  'growth': 0.1111111111111111,
#  'rings': 0.3333333333333333,
#  'live': 0.2222222222222222,
#  'long': 0.1111111111111111,
#  'time': 0.2222222222222222,
#  'give': 0.1111111111111111,
#  'idea': 0.2222222222222222,
#  'changed': 0.1111111111111111,
#  'alive': 0.1111111111111111,
#  'times': 0.3333333333333333,
#  'little': 0.2222222222222222,
#  'cooler': 0.1111111111111111,
#  'famous': 0.2222222222222222,
#  'medieval': 0.1111111111111111,
#  'period': 0.1111111111111111,
#  'cool': 0.1111111111111111,
#  'age': 0.2222222222222222,
#  'really': 0.1111111111111111,
#  'measured': 0.1111111111111111,
#  'deep': 0.1111111111111111,
#  'holes': 0.2222222222222222,
#  'bore': 0.1111111111111111,
#  'help': 0.1111111111111111,
#  'cores': 0.1111111111111111,
#  'used': 0.3333333333333333,
#  'find': 0.1111111111111111,
#  'half': 0.2222222222222222,
#  'million': 0.1111111111111111,
#  'important': 0.3333333333333333,
#  'co': 1.0,
#  'comes': 0.6,
#  'power': 0.6,
#  'burnt': 0.2,
#  'emit': 0.4,
#  'petrol': 0.2,
#  'billion': 0.2,
#  'tons': 0.2,
#  'released': 0.2,
#  'amount': 0.4,
#  'three': 0.2,
#  'quarters': 0.2,
#  'due': 0.2,
#  'rest': 0.2,
#  'cutting': 0.2,
#  'second': 0.2,
#  'production': 0.4,
#  'leaks': 0.2,
#  'dust': 0.6,
#  'dirt': 0.4,
#  'come': 0.2,
#  'sources': 0.6,
#  'volcanos': 0.2,
#  'erosion': 0.2,
#  'meteoric': 0.2,
#  'falls': 0.2,
#  'within': 0.2,
#  'hours': 0.2,
#  'aerosol': 0.4,
#  'small': 0.2,
#  'stay': 0.2,
#  'particles': 0.2,
#  'effect': 0.8,
#  'therefore': 0.2,
#  'cancels': 0.4,
#  'even': 0.2,
#  'though': 0.2,
#  'aerosols': 0.2,
#  'however': 0.4,
#  'stays': 0.2,
#  'longer': 0.2,
#  'keeps': 0.2,
#  'countries': 0.4,
#  'signed': 0.2,
#  'meant': 0.2,
#  'levels': 0.8,
#  'continued': 0.2,
#  'energy': 0.4,
#  'conservation': 0.2,
#  'solar': 0.2,
#  'panels': 0.2,
#  'electricity': 0.2,
#  'nuclear': 0.2,
#  'wind': 0.2,
#  'prevent': 0.2,
#  'getting': 0.2,
#  'capture': 0.2,
#  'storage': 0.2,
#  'ccs': 0.2,
#  'example': 0.2,
#  'go': 0.2,
#  'better': 0.2,
#  'build': 0.2,
#  'walls': 0.2,
#  'cost': 0.2,
#  'money': 0.2,
#  'rich': 0.4,
#  'able': 0.2,
#  'easily': 0.4,
#  'poor': 0.2,
#  'early': 0.4,
#  'discussing': 0.4,
#  'believed': 0.6,
#  'light': 0.2,
#  'sun': 0.4,
#  'enter': 0.2,
#  'leave': 0.2,
#  'nearly': 0.2,
#  'tried': 0.4,
#  'prove': 0.4,
#  'absorb': 0.4,
#  'infrared': 0.2,
#  'radiation': 0.2,
#  'given': 0.4,
#  'later': 0.2,
#  'john': 0.2,
#  'tyndall': 0.2,
#  'discovered': 0.2,
#  'vapor': 0.2,
#  'trap': 0.2,
#  'waves': 0.2,
#  'would': 1.0,
#  'take': 0.25,
#  'thousands': 0.25,
#  'industrial': 0.25,
#  'raise': 0.25,
#  'throughout': 0.25,
#  'th': 0.75,
#  'mid': 0.25,
#  'worked': 0.25,
#  'made': 0.25,
#  'emissions': 1.0,
#  'exponentially': 0.5,
#  'future': 0.5,
#  'surplus': 0.5,
#  'gilbert': 0.5,
#  'plass': 0.5,
#  'decided': 0.5,
#  'argued': 0.5,
#  'thinking': 0.5,
#  'ghg': 1.0,
#  'mistake': 0.5,
#  'soon': 0.5,
#  'studying': 0.5,
#  'kinds': 0.5,
#  'science': 0.5,
#  'began': 0.5,
#  'together': 0.5,
#  'mystery': 0.5,
#  'technology': 0.5,
#  'advanced': 0.5,
#  'proof': 0.5,
#  'core': 0.5,
#  'captured': 0.5,
#  'drilling': 0.5,
#  'provided': 0.5,
#  'clear': 0.5,
#  'evidence': 0.5,
#  'melting': 1.0,
#  'sheets': 1.0,
#  'antarctica': 0.5,
#  'metre': 0.5,
#  'metres': 0.5,
#  'low': 0.5,
#  'lying': 0.5,
#  'bangladesh': 0.5,
#  'florida': 0.5,
#  'netherlands': 0.5,
#  'face': 0.5,
#  'massive': 0.5,
#  'flooding': 1.0,
#  'ports': 1.0,
#  'threat': 1.0,
#  'present': 1.0,
#  'either': 1.0,
#  'trying': 1.0,
#  'deal': 1.0,
#  'related': 1.0,
#  'storm': 1.0,
#  'surge': 1.0,
#  'according': 1.0,
#  'reliable': 1.0,
#  'danger': 1.0}

# %%
sent2score = {}
for sentence in sentences:
    for word in nltk.word_tokenize(sentence.lower()):
        if word in word2count.keys():
            if len(sentence.split(' ')) < 25:
                if sentence not in sent2score.keys():
                    sent2score[sentence] = word2count[word]
                else:
                    sent2score[sentence] += word2count[word]

# %%
sent2score
# Out:
# {'global warming is the current rise in temperature of the air and oceans.': 2.9411764705882355,
#  'it happens because humans burn coal, oil and natural gas, and cut down forests.': 2.4117647058823524,
#  'sea level is rising for two reasons: ice on the land, like greenland, melts into the sea.': 3.533333333333333,
#  'water also gets larger when it warms.': 1.3333333333333333,
#  'many cities will be partly flooded by the ocean in the 21st century.': 1.2,
#  'global warming is mostly because of people burning things, like gasoline for cars and natural gas to keep houses warm.': 5.23921568627451,
#  'when people burn fossil fuels like coal, oil and natural gas this adds carbon dioxide into the air.': 7.119073083778966,
#  'this is because fossil fuels contain lots of carbon and burning means joining most of the atoms in the fuel with oxygen.': 3.9636363636363634,
#  'when people cut down many trees (deforestation), this means less carbon dioxide is taken out of the atmosphere by those plants.': 5.8855614973262025,
#  'the gas produced by cows digestion also causes global warming, because it contains a greenhouse gas called methane.': 4.632085561497326,
#  "as the earth's surface temperature becomes hotter the sea level rises.": 3.521212121212121,
#  'this is partly because water over 4 °c (39 °f) expands when it gets warmer.': 1.3818181818181818,
#  'it is also partly because warm temperatures make glaciers and ice caps melt.': 2.8819964349376113,
#  'the sea level rise causes coastal areas to flood.': 2.4196078431372547,
#  'weather patterns, including where and how much rain or snow there is, are changing.': 1.2727272727272725,
#  'deserts will probably increase in size.': 0.7272727272727273,
#  'colder areas will warm up faster than warm areas.': 2.3393939393939394,
#  'strong storms may become more likely and farming may not make as much food.': 1.9090909090909092,
#  'these effects will not be the same everywhere.': 0.36363636363636365,
#  'the changes from one area to another are not well known.': 1.0909090909090908,
#  'people in government and the intergovernmental panel on climate change (ipcc) are talking about global warming.': 3.8682115270350566,
#  'but governments, companies, and other people do not agree on what to do about it.': 1.6969696969696968,
#  'people could adapt to some temperature change.': 3.5555555555555554,
#  'the kyoto protocol and paris agreement try to reduce pollution from the burning of fossil fuels.': 3.1353535353535356,
#  'most governments have agreed to them but some people in government think nothing should change.': 2.94949494949495,
#  'climate change has happened constantly over the history of the earth, including the coming and going of ice ages.': 3.824242424242424,
#  'but modern climate change is different because people are putting carbon dioxide into the atmosphere very quickly.': 5.864646464646465,
#  'since the 1800s, people have recorded the daily temperature.': 2.3333333333333335,
#  'by about 1850, there were enough places measuring temperature so that scientists could know the global average temperature.': 4.594295900178253,
#  'compared with before people started burning a lot of coal for industry, the temperature has risen by about 1 °c (1.8 °f).': 3.8562091503267975,
#  'in 1979, satellites started measuring the temperature of the earth.': 2.62020202020202,
#  'before 1850, there were not enough temperature measurements for us to know how warm or cold it was.': 2.694949494949495,
#  'climatologists use proxy measurements to try to figure out past temperatures before there were thermometers.': 2.183006535947712,
#  'this means measuring things that change when it gets colder or warmer.': 2.7454545454545456,
#  'one way is to cut into a tree and measure how far apart the growth rings are.': 1.944147355912062,
#  'trees that live a long time can give us an idea of how temperature and rain changed while they were alive.': 2.878787878787879,
#  "for most of the past 2000 years the average temperature of the world didn't change much.": 4.0491978609625665,
#  'there were some times where the temperatures were a little warmer or cooler in some places.': 1.6941176470588235,
#  'other proxy measurements like the temperature measured in deep holes mostly agree with the tree rings.': 3.6222222222222227,
#  'tree rings and bore holes can only help scientists work out the temperature back to about 2000 years ago.': 4.41010101010101,
#  'ice cores are also used to find out the temperature back to about half a million years ago.': 4.781818181818181,
#  'there a many greenhouse gases that cause the earth to warm.': 3.527272727272727,
#  'the most important one is carbon dioxide (co2).': 2.878787878787879,
#  'co2 comes from power plants, where coal and natural gas are burnt.': 2.8171122994652404,
#  'cars also emit co2 when they burn petrol.': 1.803921568627451,
#  "about 23 billion tons of carbon dioxide and other greenhouse gases are released into the earth's atmosphere each year.": 6.187878787878788,
#  'the rest mostly comes from changes in how land is used, like cutting down trees.': 2.7454545454545456,
#  'the second most important greenhouse gas is methane.': 2.335472370766488,
#  'this comes mostly from food production.': 1.4484848484848487,
#  'some methane also leaks when oil and gas are produced.': 2.0780748663101605,
#  'dust and dirt in the air may come from natural sources such as volcanos, erosion and meteoric dust.': 4.0374331550802145,
#  'some of this dirt falls out within a few hours.': 1.0,
#  'some is aerosol, so small that it could stay in the air for years.': 2.5332144979203806,
#  'the aerosol particles in the atmosphere make the earth colder.': 2.963636363636364,
#  'the effect of dust therefore cancels out some of the effects of greenhouse gases.': 3.9090909090909087,
#  'some people burn less fossil fuel.': 3.276648841354724,
#  'countries try to emit less greenhouse gases.': 3.3030303030303028,
#  'energy conservation is used to burn less fossil fuel.': 3.2099821746880566,
#  "people can also use energy sources that don't burn fossil fuel, like solar panels or electricity from nuclear power or wind power.": 7.232204396910279,
#  'or they can prevent the carbon dioxide from getting out into the atmosphere, which is called carbon capture and storage (ccs).': 5.090909090909092,
#  'people can change how they live because of the effect of climate change.': 4.4222222222222225,
#  'for example, they can go to places where the weather is better, or build walls around cities to keep flood water out.': 2.8303030303030305,
#  'this cost money, and rich people and rich countries will be able to change more easily than the poor.': 4.4,
#  'as early as the 1820s some scientists were discussing climate change.': 2.6,
#  'joseph fourier believed that light from the sun can enter the atmosphere, but cannot leave nearly as easily.': 3.4727272727272727,
#  'he tried to prove that air can absorb the infrared radiation and will be given back to the earth’s surface.': 4.005941770647652,
#  'later in 1859, john tyndall discovered that water vapor and co2 trap heat waves given by the sun.': 2.6666666666666665,
#  'throughout the early 20th century few believed this idea.': 1.738888888888889,
#  'in 1956, gilbert n. plass decided that greenhouse gas emissions would have an effect on the earth’s temperature.': 7.738502673796791,
#  'he argued that not thinking about ghg emissions would be a mistake.': 4.5,
#  'soon after, scientists studying all different kinds of science began to work together to figure out the mystery of ghg emissions and their effects.': 6.88989898989899,
#  'as technology advanced, it was in the 1980s that there was proof of a rise in co2 levels.': 2.6529411764705886,
#  'an ice core, captured through drilling, provided clear evidence that carbon dioxide levels have risen.': 6.688888888888888,
#  'sea level is rising because water over 4 °c (39 °f) expands when it gets warmer.': 2.4484848484848483,
#  'probably more important is the melting of ice sheets.': 3.1818181818181817,
#  'the antarctica and greenland ice sheets are melting.': 3.3,
#  'many cities are sea ports and under threat of flooding if the present sea level rises.': 6.448484848484848,
#  'all other coastal cities are also in danger.': 2.1151515151515152}

# %%
import heapq

# %%
best_sentences = heapq.nlargest(10,sent2score,key=sent2score.get)

# %%
best_sentences
# Out:
# ['in 1956, gilbert n. plass decided that greenhouse gas emissions would have an effect on the earth’s temperature.',
#  "people can also use energy sources that don't burn fossil fuel, like solar panels or electricity from nuclear power or wind power.",
#  'when people burn fossil fuels like coal, oil and natural gas this adds carbon dioxide into the air.',
#  'soon after, scientists studying all different kinds of science began to work together to figure out the mystery of ghg emissions and their effects.',
#  'an ice core, captured through drilling, provided clear evidence that carbon dioxide levels have risen.',
#  'many cities are sea ports and under threat of flooding if the present sea level rises.',
#  "about 23 billion tons of carbon dioxide and other greenhouse gases are released into the earth's atmosphere each year.",
#  'when people cut down many trees (deforestation), this means less carbon dioxide is taken out of the atmosphere by those plants.',
#  'but modern climate change is different because people are putting carbon dioxide into the atmosphere very quickly.',
#  'global warming is mostly because of people burning things, like gasoline for cars and natural gas to keep houses warm.']
