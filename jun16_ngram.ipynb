# %%
text = "The climate has continuously changing for centuries. The global warming happens because the natural rotation of the sun that changes the intensity of sunlight and moving closer to the earth. Another cause of global warming is greenhouse gases. Greenhouse gases are carbon monoxide and sulphur dioxide it trap the solar heats rays and prevent it from escaping from the surface of the earth. This has cause the temperature of the earth increase. Volcanic eruptions are another issue that causes global warming. For instance, a single volcanic eruption will release amount of carbon dioxide and ash to the atmosphere. Once carbon dioxide increase, the temperature of earth increase and greenhouse trap the solar radiations in the earth. Finally, methane is another issue that causes global warming. Methane is also a greenhouse gas. Methane is more effective in trapping heat in the atmosphere that carbon dioxide by 20 times. Usually methane gas can release from many areas. For instance, it can be from cattle, landfill, natural gas, petroleum systems, coal mining, mobile explosion, or industrial waste process."""

# %%
text
# Out:
# 'The climate has continuously changing for centuries. The global warming happens because the natural rotation of the sun that changes the intensity of sunlight and moving closer to the earth. Another cause of global warming is greenhouse gases. Greenhouse gases are carbon monoxide and sulphur dioxide it trap the solar heats rays and prevent it from escaping from the surface of the earth. This has cause the temperature of the earth increase. Volcanic eruptions are another issue that causes global warming. For instance, a single volcanic eruption will release amount of carbon dioxide and ash to the atmosphere. Once carbon dioxide increase, the temperature of earth increase and greenhouse trap the solar radiations in the earth. Finally, methane is another issue that causes global warming. Methane is also a greenhouse gas. Methane is more effective in trapping heat in the atmosphere that carbon dioxide by 20 times. Usually methane gas can release from many areas. For instance, it can be from cattle, landfill, natural gas, petroleum systems, coal mining, mobile explosion, or industrial waste process.'

# %%
import random
import nltk

# %%
n = 3

# %%
ngrams = {}

# %%
words = nltk.word_tokenize(text)

# %%
words
# Out:
# ['The',
#  'climate',
#  'has',
#  'continuously',
#  'changing',
#  'for',
#  'centuries',
#  '.',
#  'The',
#  'global',
#  'warming',
#  'happens',
#  'because',
#  'the',
#  'natural',
#  'rotation',
#  'of',
#  'the',
#  'sun',
#  'that',
#  'changes',
#  'the',
#  'intensity',
#  'of',
#  'sunlight',
#  'and',
#  'moving',
#  'closer',
#  'to',
#  'the',
#  'earth',
#  '.',
#  'Another',
#  'cause',
#  'of',
#  'global',
#  'warming',
#  'is',
#  'greenhouse',
#  'gases',
#  '.',
#  'Greenhouse',
#  'gases',
#  'are',
#  'carbon',
#  'monoxide',
#  'and',
#  'sulphur',
#  'dioxide',
#  'it',
#  'trap',
#  'the',
#  'solar',
#  'heats',
#  'rays',
#  'and',
#  'prevent',
#  'it',
#  'from',
#  'escaping',
#  'from',
#  'the',
#  'surface',
#  'of',
#  'the',
#  'earth',
#  '.',
#  'This',
#  'has',
#  'cause',
#  'the',
#  'temperature',
#  'of',
#  'the',
#  'earth',
#  'increase',
#  '.',
#  'Volcanic',
#  'eruptions',
#  'are',
#  'another',
#  'issue',
#  'that',
#  'causes',
#  'global',
#  'warming',
#  '.',
#  'For',
#  'instance',
#  ',',
#  'a',
#  'single',
#  'volcanic',
#  'eruption',
#  'will',
#  'release',
#  'amount',
#  'of',
#  'carbon',
#  'dioxide',
#  'and',
#  'ash',
#  'to',
#  'the',
#  'atmosphere',
#  '.',
#  'Once',
#  'carbon',
#  'dioxide',
#  'increase',
#  ',',
#  'the',
#  'temperature',
#  'of',
#  'earth',
#  'increase',
#  'and',
#  'greenhouse',
#  'trap',
#  'the',
#  'solar',
#  'radiations',
#  'in',
#  'the',
#  'earth',
#  '.',
#  'Finally',
#  ',',
#  'methane',
#  'is',
#  'another',
#  'issue',
#  'that',
#  'causes',
#  'global',
#  'warming',
#  '.',
#  'Methane',
#  'is',
#  'also',
#  'a',
#  'greenhouse',
#  'gas',
#  '.',
#  'Methane',
#  'is',
#  'more',
#  'effective',
#  'in',
#  'trapping',
#  'heat',
#  'in',
#  'the',
#  'atmosphere',
#  'that',
#  'carbon',
#  'dioxide',
#  'by',
#  '20',
#  'times',
#  '.',
#  'Usually',
#  'methane',
#  'gas',
#  'can',
#  'release',
#  'from',
#  'many',
#  'areas',
#  '.',
#  'For',
#  'instance',
#  ',',
#  'it',
#  'can',
#  'be',
#  'from',
#  'cattle',
#  ',',
#  'landfill',
#  ',',
#  'natural',
#  'gas',
#  ',',
#  'petroleum',
#  'systems',
#  ',',
#  'coal',
#  'mining',
#  ',',
#  'mobile',
#  'explosion',
#  ',',
#  'or',
#  'industrial',
#  'waste',
#  'process',
#  '.']

# %%
len(words)
# Out:
# 198

# %%
for i in range(len(words)-n):
    gram = ' '.join(words[i:i+n]) #0----> 2
    if gram not in ngrams.keys():
        ngrams[gram] = []
    ngrams[gram].append(words[i+n])

# %%
ngrams
# Out:
# {'The climate has': ['continuously'],
#  'climate has continuously': ['changing'],
#  'has continuously changing': ['for'],
#  'continuously changing for': ['centuries'],
#  'changing for centuries': ['.'],
#  'for centuries .': ['The'],
#  'centuries . The': ['global'],
#  '. The global': ['warming'],
#  'The global warming': ['happens'],
#  'global warming happens': ['because'],
#  'warming happens because': ['the'],
#  'happens because the': ['natural'],
#  'because the natural': ['rotation'],
#  'the natural rotation': ['of'],
#  'natural rotation of': ['the'],
#  'rotation of the': ['sun'],
#  'of the sun': ['that'],
#  'the sun that': ['changes'],
#  'sun that changes': ['the'],
#  'that changes the': ['intensity'],
#  'changes the intensity': ['of'],
#  'the intensity of': ['sunlight'],
#  'intensity of sunlight': ['and'],
#  'of sunlight and': ['moving'],
#  'sunlight and moving': ['closer'],
#  'and moving closer': ['to'],
#  'moving closer to': ['the'],
#  'closer to the': ['earth'],
#  'to the earth': ['.'],
#  'the earth .': ['Another', 'This', 'Finally'],
#  'earth . Another': ['cause'],
#  '. Another cause': ['of'],
#  'Another cause of': ['global'],
#  'cause of global': ['warming'],
#  'of global warming': ['is'],
#  'global warming is': ['greenhouse'],
#  'warming is greenhouse': ['gases'],
#  'is greenhouse gases': ['.'],
#  'greenhouse gases .': ['Greenhouse'],
#  'gases . Greenhouse': ['gases'],
#  '. Greenhouse gases': ['are'],
#  'Greenhouse gases are': ['carbon'],
#  'gases are carbon': ['monoxide'],
#  'are carbon monoxide': ['and'],
#  'carbon monoxide and': ['sulphur'],
#  'monoxide and sulphur': ['dioxide'],
#  'and sulphur dioxide': ['it'],
#  'sulphur dioxide it': ['trap'],
#  'dioxide it trap': ['the'],
#  'it trap the': ['solar'],
#  'trap the solar': ['heats', 'radiations'],
#  'the solar heats': ['rays'],
#  'solar heats rays': ['and'],
#  'heats rays and': ['prevent'],
#  'rays and prevent': ['it'],
#  'and prevent it': ['from'],
#  'prevent it from': ['escaping'],
#  'it from escaping': ['from'],
#  'from escaping from': ['the'],
#  'escaping from the': ['surface'],
#  'from the surface': ['of'],
#  'the surface of': ['the'],
#  'surface of the': ['earth'],
#  'of the earth': ['.', 'increase'],
#  'earth . This': ['has'],
#  '. This has': ['cause'],
#  'This has cause': ['the'],
#  'has cause the': ['temperature'],
#  'cause the temperature': ['of'],
#  'the temperature of': ['the', 'earth'],
#  'temperature of the': ['earth'],
#  'the earth increase': ['.'],
#  'earth increase .': ['Volcanic'],
#  'increase . Volcanic': ['eruptions'],
#  '. Volcanic eruptions': ['are'],
#  'Volcanic eruptions are': ['another'],
#  'eruptions are another': ['issue'],
#  'are another issue': ['that'],
#  'another issue that': ['causes', 'causes'],
#  'issue that causes': ['global', 'global'],
#  'that causes global': ['warming', 'warming'],
#  'causes global warming': ['.', '.'],
#  'global warming .': ['For', 'Methane'],
#  'warming . For': ['instance'],
#  '. For instance': [',', ','],
#  'For instance ,': ['a', 'it'],
#  'instance , a': ['single'],
#  ', a single': ['volcanic'],
#  'a single volcanic': ['eruption'],
#  'single volcanic eruption': ['will'],
#  'volcanic eruption will': ['release'],
#  'eruption will release': ['amount'],
#  'will release amount': ['of'],
#  'release amount of': ['carbon'],
#  'amount of carbon': ['dioxide'],
#  'of carbon dioxide': ['and'],
#  'carbon dioxide and': ['ash'],
#  'dioxide and ash': ['to'],
#  'and ash to': ['the'],
#  'ash to the': ['atmosphere'],
#  'to the atmosphere': ['.'],
#  'the atmosphere .': ['Once'],
#  'atmosphere . Once': ['carbon'],
#  '. Once carbon': ['dioxide'],
#  'Once carbon dioxide': ['increase'],
#  'carbon dioxide increase': [','],
#  'dioxide increase ,': ['the'],
#  'increase , the': ['temperature'],
#  ', the temperature': ['of'],
#  'temperature of earth': ['increase'],
#  'of earth increase': ['and'],
#  'earth increase and': ['greenhouse'],
#  'increase and greenhouse': ['trap'],
#  'and greenhouse trap': ['the'],
#  'greenhouse trap the': ['solar'],
#  'the solar radiations': ['in'],
#  'solar radiations in': ['the'],
#  'radiations in the': ['earth'],
#  'in the earth': ['.'],
#  'earth . Finally': [','],
#  '. Finally ,': ['methane'],
#  'Finally , methane': ['is'],
#  ', methane is': ['another'],
#  'methane is another': ['issue'],
#  'is another issue': ['that'],
#  'warming . Methane': ['is'],
#  '. Methane is': ['also', 'more'],
#  'Methane is also': ['a'],
#  'is also a': ['greenhouse'],
#  'also a greenhouse': ['gas'],
#  'a greenhouse gas': ['.'],
#  'greenhouse gas .': ['Methane'],
#  'gas . Methane': ['is'],
#  'Methane is more': ['effective'],
#  'is more effective': ['in'],
#  'more effective in': ['trapping'],
#  'effective in trapping': ['heat'],
#  'in trapping heat': ['in'],
#  'trapping heat in': ['the'],
#  'heat in the': ['atmosphere'],
#  'in the atmosphere': ['that'],
#  'the atmosphere that': ['carbon'],
#  'atmosphere that carbon': ['dioxide'],
#  'that carbon dioxide': ['by'],
#  'carbon dioxide by': ['20'],
#  'dioxide by 20': ['times'],
#  'by 20 times': ['.'],
#  '20 times .': ['Usually'],
#  'times . Usually': ['methane'],
#  '. Usually methane': ['gas'],
#  'Usually methane gas': ['can'],
#  'methane gas can': ['release'],
#  'gas can release': ['from'],
#  'can release from': ['many'],
#  'release from many': ['areas'],
#  'from many areas': ['.'],
#  'many areas .': ['For'],
#  'areas . For': ['instance'],
#  'instance , it': ['can'],
#  ', it can': ['be'],
#  'it can be': ['from'],
#  'can be from': ['cattle'],
#  'be from cattle': [','],
#  'from cattle ,': ['landfill'],
#  'cattle , landfill': [','],
#  ', landfill ,': ['natural'],
#  'landfill , natural': ['gas'],
#  ', natural gas': [','],
#  'natural gas ,': ['petroleum'],
#  'gas , petroleum': ['systems'],
#  ', petroleum systems': [','],
#  'petroleum systems ,': ['coal'],
#  'systems , coal': ['mining'],
#  ', coal mining': [','],
#  'coal mining ,': ['mobile'],
#  'mining , mobile': ['explosion'],
#  ', mobile explosion': [','],
#  'mobile explosion ,': ['or'],
#  'explosion , or': ['industrial'],
#  ', or industrial': ['waste'],
#  'or industrial waste': ['process'],
#  'industrial waste process': ['.']}

# %%
# text generation

# %%
currentGram = ' '.join(words[0:n])

# %%
currentGram
# Out:
# 'The climate has'

# %%
result = currentGram
for i in range(50):
    if currentGram not in ngrams.keys():
        break
    possibilities = ngrams[currentGram]
    nextItem = possibilities[random.randrange(len(possibilities))]
    result += ' '+nextItem
    rwords = nltk.word_tokenize(result)
    currentGram = ' '.join(rwords[len(rwords)-n:len(rwords)])
print(result)
# Out:
# The climate has continuously changing for centuries . The global warming happens because the natural rotation of the sun that changes the intensity of sunlight and moving closer to the earth . Another cause of global warming is greenhouse gases . Greenhouse gases are carbon monoxide and sulphur dioxide it trap the solar
